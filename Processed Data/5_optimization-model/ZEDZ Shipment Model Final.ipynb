# %% [markdown]
# Author: Matthew Forbes
# Date: May 12th, 2022
# ZEDZ Shipment Model for APP
#
# The following code produces estimates for the total driving distance conducted by delivery vehicles in the City of Santa Monica. It also produces estimates on how these driving distances change when different ZEDZ policies are imposed, using the boundaries of the voluntary-ZEDZ that is currently being implemented.
#
# This model is based on "Application of an empirical multi-agent model for urban goods transport to analyze impacts of zero emission zones in The Netherlands" by Michiel de Bok, Lorant Tavasszy, and Sebastiaan Thoen: https://www.sciencedirect.com/science/article/pii/S0967070X19307383. The model contains three main parts: shipment synthesizer, tour formation, and network assignment.
#
# The first part, shipment synthesizer, is tasked with generating a dataframe of possible shipments that could plausibly occur on an average day. This dataframe contains the following for each generated shipment:
# ● The name and location of the sender;
# ● The name and location of the receiver;
# ● The company that is conducting this shipment
#
# The second section, tour formation, is concerned with estimating the number of shipments contained in a single shipment route and then grouping these shipments together (i.e. can multiple shipments be completed in a single tour of a shipment vehicle, and if so which shipments are likely to be grouped together).
#
# The third section, network assignment, attempts to predict the potential routes that vehicles will take to complete these tours. These estimates are derived simply by mapping the shortest path from the sender location that connects all recipient locations.
#
# Inputs (these need to be in your working directory)(author: Ryota Abe):
# - "consumer_nodes edited.csv"
# - "depot_nodes edited.csv"
# - "Entire Nodes.xlsx"
# - "consumer_nodes_new.csv"
# - "depot-x_arccs.xlsx" with x being 1 through 16
#
# Outputs:
# - "FinalResults - status quo dist.xlsx"
#     -the total distance driven in meters by each company and in total under no policy
# - "FinalResults - mandatory ZEDZ dist.xlsx"
#     -the total distance driven in meters by each company and in total under a mandatory ZEDZ policy
# - "FinalResults - status quo tours.xlsx"
#     -the number of vehicle tours conducted by each company and in total under no policy
# - "FinalResults - mandatory ZEDZ tours.xlsx"
#     -the number of vehicle tours conducted by each company and in total under a mandatory ZEDZ policy
# - "FinalResults - status quo vehicles.xlsx"
#     -the distance driven by tour and vehicle under no policy
# - "FinalResults - mandatory ZEDZ vehicles.xlsx"
#     -the distance driven by tour and vehicle under a mandatory ZEDZ policy
#
# *Model description taken from our APP report

# %%
#Import Statements
import pandas as pd 
import numpy as np
import random

# %%
#Import consumer nodes
consumer_nodes = pd.read_csv("consumer_nodes edited.csv")
consumer_nodes
# Out:
#      street_id                           street_address   latitude  \
# 0            1        10th Court, Santa Monica, CA90403  34.019890
# 1            2        10th Court, Santa Monica, CA90405  34.019897
# 2            3       10th Street, Santa Monica, CA90401  34.019890
# 3            4       10th Street, Santa Monica, CA90402  34.019890
# 4            5       10th Street, Santa Monica, CA90403  34.019890
# ..         ...                                      ...        ...
# 346        347     Winnett Place, Santa Monica, CA90402  34.031853
# 347        348    Woodacres Road, Santa Monica, CA90402  34.039950
# 348        349       Yale Street, Santa Monica, CA90403  34.038366
# 349        350       Yale Street, Santa Monica, CA90404  34.034314
# 350        351  Yorkshire Avenue, Santa Monica, CA90404  34.026252
#
#       longitude  ZEDZ(inside =1)  pop_distribution  parcel_delivered(#/year)  \
# 0   -118.488409                0        263.125356               7367.509972
# 1   -118.487261                0        263.125356               7367.509972
# 2   -118.488409                0        263.125356               7367.509972
# 3   -118.488409                0        263.125356               7367.509972
# 4   -118.488409                0        263.125356               7367.509972
# ..          ...              ...               ...                       ...
# 346 -118.502660                0        263.125356               7367.509972
# 347 -118.505475                0        263.125356               7367.509972
# 348 -118.475060                0        263.125356               7367.509972
# 349 -118.470567                0        263.125356               7367.509972
# 350 -118.461364                0        263.125356               7367.509972
#
#      parcel_delivered(#/day)  parcel_delivered(kg/day) USPS_Depot_name  ...  \
# 0                  20.184959                 22.203455         depot-5  ...
# 1                  20.184959                 22.203455         depot-5  ...
# 2                  20.184959                 22.203455         depot-5  ...
# 3                  20.184959                 22.203455         depot-5  ...
# 4                  20.184959                 22.203455         depot-5  ...
# ..                       ...                       ...             ...  ...
# 346                20.184959                 22.203455         depot-1  ...
# 347                20.184959                 22.203455         depot-1  ...
# 348                20.184959                 22.203455         depot-2  ...
# 349                20.184959                 22.203455         depot-3  ...
# 350                20.184959                 22.203455         depot-5  ...
#
#      UPS_Depot_name UPS_Depot_parcel(kg)  Amazon_Depot_name  \
# 0           depot-9             5.328829           depot-10
# 1           depot-9             5.328829           depot-10
# 2           depot-9             5.328829           depot-10
# 3           depot-9             5.328829           depot-10
# 4           depot-9             5.328829           depot-10
# ..              ...                  ...                ...
# 346         depot-9             5.328829           depot-10
# 347         depot-9             5.328829           depot-10
# 348         depot-9             5.328829           depot-10
# 349         depot-9             5.328829           depot-10
# 350         depot-9             5.328829           depot-10
#
#     Amazon_Depot_Depot_parcel(kg)  FedEX_Depot_name FedEX_Depot_parcel(kg)  \
# 0                        4.662725          depot-12               3.996622
# 1                        4.662725          depot-12               3.996622
# 2                        4.662725          depot-12               3.996622
# 3                        4.662725          depot-12               3.996622
# 4                        4.662725          depot-12               3.996622
# ..                            ...               ...                    ...
# 346                      4.662725          depot-12               3.996622
# 347                      4.662725          depot-12               3.996622
# 348                      4.662725          depot-13               3.996622
# 349                      4.662725          depot-14               3.996622
# 350                      4.662725          depot-14               3.996622
#
#      USPS_ID  UPS_ID  Amazon_ID  FedEx_ID
# 0          5       9         10        12
# 1          5       9         10        12
# 2          5       9         10        12
# 3          5       9         10        12
# 4          5       9         10        12
# ..       ...     ...        ...       ...
# 346        1       9         10        12
# 347        1       9         10        12
# 348        2       9         10        13
# 349        3       9         10        14
# 350        5       9         10        14
#
# [351 rows x 21 columns]

# %%
#import logistic nodes
logistic_nodes = pd.read_csv("depot_nodes edited.csv")
logistic_nodes
# Out:
#     logistics_company_id logistics_company_name  logistics_company_share  \
# 0                      1                   USPS                     0.38
# 1                      1                   USPS                     0.38
# 2                      1                   USPS                     0.38
# 3                      1                   USPS                     0.38
# 4                      1                   USPS                     0.38
# 5                      1                   USPS                     0.38
# 6                      1                   USPS                     0.38
# 7                      1                   USPS                     0.38
# 8                      2                    UPS                     0.24
# 9                      3       Amazon Logistics                     0.21
# 10                     4                  FedEx                     0.18
# 11                     4                  FedEx                     0.18
# 12                     4                  FedEx                     0.18
# 13                     4                  FedEx                     0.18
# 14                     4                  FedEx                     0.18
# 15                     4                  FedEx                     0.18
#
#     depot_id  depot_share  depot_parcel(#)  depot_parcel(kg)  \
# 0          1     0.130772       935.774691       1029.352160
# 1          2     0.012863        92.043412        101.247754
# 2          3     0.052523        92.043412        413.428327
# 3          4     0.005360        92.043412         42.186564
# 4          5     0.056811        92.043412        447.177578
# 5          6     0.099687        92.043412        784.670089
# 6          7     0.003216        92.043412         25.311938
# 7          8     0.015007        92.043412        118.122379
# 8          9     0.237624        92.043412       1870.419025
# 9         10     0.207921        92.043412       1636.616647
# 10        11     0.058390        92.043412        459.611513
# 11        12     0.036050        92.043412        283.760151
# 12        13     0.004062        92.043412         31.972975
# 13        14     0.071592        92.043412        563.523680
# 14        15     0.003554        92.043412         27.976353
# 15        16     0.004570        92.043412         35.969597
#
#                                         depot_address  depot_latitude  \
# 0            1112 Montana Ave, Santa Monica, CA 90403       34.030044
# 1            1626 Montana Ave, Santa Monica, CA 90403       34.034159
# 2          1223 Wilshire Blvd, Santa Monica, CA 90403       34.025935
# 3          1217 Wilshire Blvd, Santa Monica, CA 90403       34.025861
# 4                 1653 7th St, Santa Monica, CA 90404       34.015040
# 5       2720 Neilson Way Fl 1, Santa Monica, CA 90405       33.999954
# 6                    313 Grand Blvd, Venice, CA 90291       33.988641
# 7         3826 Grand View Blvd, Los Angeles, CA 90066       34.004446
# 8      10690 Santa Monica Blvd, Los Angeles, CA 90025       34.051950
# 9        5750 Mesmer Ave STE D, Culver City, CA 90230       33.984066
# 10          408 Wilshire Blvd, Santa Monica, CA 90401       34.019282
# 11         1006 Wilshire Blvd, Santa Monica, CA 90401       34.023789
# 12  2300 Wilshire Blvd Suite 102, Santa Monica, CA...       34.033276
# 13     2309 Santa Monica Blvd, Santa Monica, CA 90404       34.031072
# 14         4170 Del Rey Ave, Marina Del Rey, CA 90292       33.987807
# 15  13488 Maxella Ave Suite 300, Marina Del Rey, C...       33.985866
#
#     depot_longitude  ZEDZ(inside =1)
# 0       -118.497416                0
# 1       -118.492490                0
# 2       -118.490306                0
# 3       -118.490424                0
# 4       -118.487514                1
# 5       -118.482961                1
# 6       -118.469427                0
# 7       -118.430180                0
# 8       -118.431388                0
# 9       -118.398651                0
# 10      -118.497775                1
# 11      -118.492240                0
# 12      -118.480133                0
# 13      -118.477405                0
# 14      -118.443532                0
# 15      -118.442557                0

# %%
#Import depot arcs
depot_1 = pd.read_excel("depot-1_arccs.xlsx")
depot_2 = pd.read_excel("depot-2_arcs.xlsx")
depot_3 = pd.read_excel("depot-3_arcs.xlsx")
depot_4 = pd.read_excel("depot-4_arccs.xlsx")
depot_5 = pd.read_excel("depot-5_arccs.xlsx")
depot_6 = pd.read_excel("depot-6_arccs.xlsx")
depot_7 = pd.read_excel("depot-7_arccs.xlsx")
depot_8 = pd.read_excel("depot-8_arccs.xlsx")
depot_9 = pd.read_excel("depot-9_arccs.xlsx")
depot_10 = pd.read_excel("depot-10_arccs.xlsx")
depot_11 = pd.read_excel("depot-11_arccs.xlsx")
depot_12 = pd.read_excel("depot-12_arccs.xlsx")
depot_13 = pd.read_excel("depot-13_arccs.xlsx")
depot_14 = pd.read_excel("depot-14_arccs.xlsx")
depot_15 = pd.read_excel("depot-15_arccs.xlsx")
depot_16 = pd.read_excel("depot-16_arccs.xlsx")

# %%
#Merge depot dataframes together
depot_arcs = pd.concat([depot_1, depot_2, depot_3, depot_4, depot_5, depot_6, depot_7, depot_8, depot_9, depot_10, depot_11, depot_12, depot_13, depot_14, depot_15, depot_16])
depot_arcs
# Out:
#     Unnamed: 0  Distance in meter  duration in seconds  origin_id  \
# 0            0                  0                    0          1
# 1            1                 24                   85          1
# 2            2               1339                  231          1
# 3            3               1339                  231          1
# 4            4               1380                  255          1
# ..         ...                ...                  ...        ...
# 96          96              26921                 1581        313
# 97          97               4030                  492        313
# 98          98               1643                  212        313
# 99          99                  0                    0        313
# 0            0                  0                    0         16
#
#     destination_id  ID_x  longitude_x  latitude_x location_x  ID_y  \
# 0                1     1  -118.497420   34.030040    Depot-1     1
# 1               24     1  -118.497420   34.030040    Depot-1    24
# 2               91     1  -118.497420   34.030040    Depot-1    91
# 3               93     1  -118.497420   34.030040    Depot-1    93
# 4              106     1  -118.497420   34.030040    Depot-1   106
# ..             ...   ...          ...         ...        ...   ...
# 96             299   313  -118.449599   34.014784        NaN   299
# 97             310   313  -118.449599   34.014784        NaN   310
# 98             312   313  -118.449599   34.014784        NaN   312
# 99             313   313  -118.449599   34.014784        NaN   313
# 0               16    16  -118.442560   33.985870        NaN    16
#
#     longitude_y  latitude_y location_y spot_x spot_y    city_x    city_y
# 0   -118.497420   34.030040    Depot-1    NaN    NaN       NaN       NaN
# 1   -118.497364   34.029789   Street-8    NaN    NaN       NaN       NaN
# 2   -118.506132   34.022201  Street-75    NaN    NaN       NaN       NaN
# 3   -118.506132   34.022201  Street-77    NaN    NaN       NaN       NaN
# 4   -118.500623   34.021548  Street-90    NaN    NaN       NaN       NaN
# ..          ...         ...        ...    ...    ...       ...       ...
# 96  -118.247567   34.086434        NaN    NaN    NaN       NaN       NaN
# 97  -118.454339   33.995917        NaN    NaN    NaN       NaN       NaN
# 98  -118.463517   34.006780        NaN    NaN    NaN       NaN       NaN
# 99  -118.449599   34.014784        NaN    NaN    NaN       NaN       NaN
# 0   -118.442560   33.985870        NaN    NaN    NaN  Depot-16  Depot-16
#
# [356436 rows x 17 columns]

# %%
#Import Entire Nodes dataset
entire_nodes = pd.read_excel("Entire Nodes.xlsx")
entire_nodes
# Out:
#       ID depot_id street_id   longitude   latitude    location USPS Depot  \
# 0      1        1         - -118.497420  34.030040     Depot-1    Depot-1
# 1      2        2         - -118.492490  34.034160     Depot-2    Depot-2
# 2      3        3         - -118.490310  34.025930     Depot-3    Depot-3
# 3      4        4         - -118.490420  34.025860     Depot-4    Depot-4
# 4      5        5         - -118.487510  34.015040     Depot-5    Depot-5
# ..   ...      ...       ...         ...        ...         ...        ...
# 362  363        -       347 -118.502660  34.031853  Street-347    Depot-1
# 363  364        -       348 -118.505475  34.039950  Street-348    Depot-1
# 364  365        -       349 -118.475060  34.038366  Street-349    Depot-2
# 365  366        -       350 -118.470567  34.034314  Street-350    Depot-3
# 366  367        -       351 -118.461364  34.026252  Street-351    Depot-5
#
#        pd(kg) UPS Depot  pd(kg).1 Amazon Depot  pd(kg).2 FedEX Depot  pd(kg).3
# 0           -         -         -            -         -           -         -
# 1           -         -         -            -         -           -         -
# 2           -         -         -            -         -           -         -
# 3           -         -         -            -         -           -         -
# 4           -         -         -            -         -           -         -
# ..        ...       ...       ...          ...       ...         ...       ...
# 362  8.437313   Depot-9  5.328829     Depot-10  4.662725    Depot-12  3.996622
# 363  8.437313   Depot-9  5.328829     Depot-10  4.662725    Depot-12  3.996622
# 364  8.437313   Depot-9  5.328829     Depot-10  4.662725    Depot-13  3.996622
# 365  8.437313   Depot-9  5.328829     Depot-10  4.662725    Depot-14  3.996622
# 366  8.437313   Depot-9  5.328829     Depot-10  4.662725    Depot-14  3.996622
#
# [367 rows x 14 columns]

# %% [markdown]
# <font size="5">Part I: Shipment Synthesizer</font>

# %%
#Part 1.1: Depot Proportions
#This part declares the proportions of shipments that originate from each logistic depot

depots = logistic_nodes["depot_id"]
depot_share = logistic_nodes["depot_share"]

#Share of shipments that originate from each company (data from APP report)
company_share = [0.38, 0.24, 0.21, 0.17]
company_names = ["USPS", "UPS", "Amazon Logistics", "FedEx"]

parcels_per_day = pd.read_csv("consumer_nodes_new.csv")
parcels_per_day = parcels_per_day["parcel_delivered(#/day)"].tolist()
parcels_per_day = [round(num) for num in parcels_per_day]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19152/2056827247.py in <module>
#       2 #This part declares the proportions of shipments that originate from each logistic depot
#       3
# ----> 4 depots = logistic_nodes["depot_id"]
#       5 depot_share = logistic_nodes["depot_share"]
#       6
#
# NameError: name 'logistic_nodes' is not defined

# %%
#Part 1.2: Generate Shipments

#The list of consumer node IDs
consumer_ids = consumer_nodes["street_id"]

#Dataframe that will ultimately contain all shipment data
shipment_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])

#Inputs a consumer node, and outputs the appropriate depot based on the company share proportions and the nearest depots to the consumer node.
def which_sender(consumer_id):
    the_consumer = consumer_nodes.iloc[consumer_id]
    the_business = np.random.choice( company_names, 1, p = company_share)
    if the_business[0] == "USPS":
        return the_consumer["USPS_ID"]
    if the_business[0] == "UPS":
        return the_consumer["UPS_ID"]
    if the_business[0] == "Amazon Logistics":
        return the_consumer["Amazon_ID"]
    if the_business[0] == "FedEx":
        return the_consumer["FedEx_ID"]
    
#Copy of consumer_node Dataframe
num_shipments = consumer_nodes

#Combines consumer and depot node information into the shipment_df dataframe, and selects appropriate sender depot for shipment to each node.
for i in range(len(consumer_ids)):
    ship_per_node =  parcels_per_day[i]
    for j in range(ship_per_node):
        receiver = consumer_nodes.iloc[i]
        sender_id = which_sender(i)
        sender = logistic_nodes.loc[logistic_nodes["depot_id"] == sender_id]

        receiver_id = receiver["street_id"]
        receiver_lat = receiver["latitude"]
        receiver_lon = receiver["longitude"]
        receiver_name = receiver["street_address"]
        rec_ZEDZ = receiver["ZEDZ(inside =1)"]

        sender_name = sender.iloc[0]["logistics_company_name"]
        sender_lat = sender.iloc[0]["depot_latitude"]
        sender_lon = sender.iloc[0]["depot_longitude"]
        sen_ZEDZ = sender.iloc[0]["ZEDZ(inside =1)"]
    
        shipment_df.loc[len(shipment_df.index)] = [receiver_name, receiver_id, receiver_lat, receiver_lon, rec_ZEDZ, sender_name, sender_id, sender_lat, sender_lon, sen_ZEDZ]
    




#Calculates the distance between each consumer node and its depot
ship_dist = []
for i in range(shipment_df[shipment_df.columns[0]].count()):
    the_shipment = shipment_df.iloc[[i]]
    the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
    the_depot_id = the_shipment.iloc[0]["Sender_ID"]
    #Get the Entire_nodes ID for the receiver
    rec_node = entire_nodes[entire_nodes['street_id'] == the_ship_id]
    receiver_entire_ID = rec_node.iloc[0]["ID"]
    #Get the Entire_nodes ID for the sender
    sen_node = entire_nodes[entire_nodes["depot_id"] == the_depot_id ]
    sender_entire_ID = sen_node.iloc[0]["ID"]

    
    poss_depo_arcs = depot_arcs[depot_arcs['origin_id'] == sender_entire_ID]
    the_arc = poss_depo_arcs[poss_depo_arcs['destination_id'] == receiver_entire_ID]
    the_arc_dist = the_arc.iloc[0]['Distance in meter']
    
    ship_dist.append(the_arc_dist)

#Adds distances to shipment_df
shipment_df["Distance"] = ship_dist
 
shipment_df
# Out:
# the shipID
# 1
# the depotID
# 9
# rec entire:
# 17
# sen entire:
# 9
# count
# 0
# the shipID
# 1
# the depotID
# 12
# rec entire:
# 17
# sen entire:
# 12
# count
# 1
# the shipID
# 1
# the depotID
# 12
# rec entire:
# 17
# sen entire:
# 12
# count
# 2
# the shipID
# 1
# the depotID
# 5
# rec entire:
# 17
# sen entire:
# 5
# count
# 3
# the shipID
# 1
# the depotID
# 5
# rec entire:
# 17
# sen entire:
# 5
# count
# 4
# the shipID
# 1
# the depotID
# 5
# rec entire:
# 17
# sen entire:
# 5
# count
# 5
# the shipID
# 1
# the depotID
# 10
# rec entire:
# 17
# sen entire:
# 10
# count
# 6
# the shipID
# 1
# the depotID
# 9
# rec entire:
# 17
# sen entire:
# 9
# count
# 7
# the shipID
# 1
# the depotID
# 9
# rec entire:
# 17
# sen entire:
# 9
# count
# 8
# the shipID
# 1
# the depotID
# 5
# rec entire:
# 17
# sen entire:
# 5
# count
# 9
# the shipID
# 1
# the depotID
# 5
# rec entire:
# 17
# sen entire:
# 5
# count
# 10
# the shipID
# 1
# the depotID
# 5
# rec entire:
# 17
# sen entire:
# 5
# count
# 11
# the shipID
# 2
# the depotID
# 9
# rec entire:
# 18
# sen entire:
# 9
# count
# 12
# the shipID
# 2
# the depotID
# 9
# rec entire:
# 18
# sen entire:
# 9
# count
# 13
# the shipID
# 2
# the depotID
# 10
# rec entire:
# 18
# sen entire:
# 10
# count
# 14
# the shipID
# 2
# the depotID
# 12
# rec entire:
# 18
# sen entire:
# 12
# count
# 15
# the shipID
# 2
# the depotID
# 5
# rec entire:
# 18
# sen entire:
# 5
# count
# 16
# the shipID
# 2
# the depotID
# 9
# rec entire:
# 18
# sen entire:
# 9
# count
# 17
# the shipID
# 2
# the depotID
# 9
# rec entire:
# 18
# sen entire:
# 9
# count
# 18
# the shipID
# 2
# the depotID
# 5
# rec entire:
# 18
# sen entire:
# 5
# count
# 19
# the shipID
# 2
# the depotID
# 9
# rec entire:
# 18
# sen entire:
# 9
# count
# 20
# the shipID
# 2
# the depotID
# 12
# rec entire:
# 18
# sen entire:
# 12
# count
# 21
# the shipID
# 2
# the depotID
# 12
# rec entire:
# 18
# sen entire:
# 12
# count
# 22
# the shipID
# 2
# the depotID
# 12
# rec entire:
# 18
# sen entire:
# 12
# count
# 23
# the shipID
# 3
# the depotID
# 12
# rec entire:
# 19
# sen entire:
# 12
# count
# 24
# the shipID
# 3
# the depotID
# 5
# rec entire:
# 19
# sen entire:
# 5
# count
# 25
# the shipID
# 3
# the depotID
# 5
# rec entire:
# 19
# sen entire:
# 5
# count
# 26
# the shipID
# 3
# the depotID
# 12
# rec entire:
# 19
# sen entire:
# 12
# count
# 27
# the shipID
# 3
# the depotID
# 12
# rec entire:
# 19
# sen entire:
# 12
# count
# 28
# the shipID
# 3
# the depotID
# 5
# rec entire:
# 19
# sen entire:
# 5
# count
# 29
# the shipID
# 3
# the depotID
# 5
# rec entire:
# 19
# sen entire:
# 5
# count
# 30
# the shipID
# 3
# the depotID
# 5
# rec entire:
# 19
# sen entire:
# 5
# count
# 31
# the shipID
# 3
# the depotID
# 12
# rec entire:
# 19
# sen entire:
# 12
# count
# 32
# the shipID
# 3
# the depotID
# 9
# rec entire:
# 19
# sen entire:
# 9
# count
# 33
# the shipID
# 3
# the depotID
# 12
# rec entire:
# 19
# sen entire:
# 12
# count
# 34
# the shipID
# 3
# the depotID
# 9
# rec entire:
# 19
# sen entire:
# 9
# count
# 35
# the shipID
# 4
# the depotID
# 10
# rec entire:
# 20
# sen entire:
# 10
# count
# 36
# the shipID
# 4
# the depotID
# 5
# rec entire:
# 20
# sen entire:
# 5
# count
# 37
# the shipID
# 4
# the depotID
# 5
# rec entire:
# 20
# sen entire:
# 5
# count
# 38
# the shipID
# 4
# the depotID
# 12
# rec entire:
# 20
# sen entire:
# 12
# count
# 39
# the shipID
# 4
# the depotID
# 9
# rec entire:
# 20
# sen entire:
# 9
# count
# 40
# the shipID
# 4
# the depotID
# 12
# rec entire:
# 20
# sen entire:
# 12
# count
# 41
# the shipID
# 4
# the depotID
# 12
# rec entire:
# 20
# sen entire:
# 12
# count
# 42
# the shipID
# 4
# the depotID
# 5
# rec entire:
# 20
# sen entire:
# 5
# count
# 43
# the shipID
# 4
# the depotID
# 5
# rec entire:
# 20
# sen entire:
# 5
# count
# 44
# the shipID
# 4
# the depotID
# 12
# rec entire:
# 20
# sen entire:
# 12
# count
# 45
# the shipID
# 4
# the depotID
# 12
# rec entire:
# 20
# sen entire:
# 12
# count
# 46
# the shipID
# 4
# the depotID
# 12
# rec entire:
# 20
# sen entire:
# 12
# count
# 47
# the shipID
# 5
# the depotID
# 9
# rec entire:
# 21
# sen entire:
# 9
# count
# 48
# the shipID
# 5
# the depotID
# 5
# rec entire:
# 21
# sen entire:
# 5
# count
# 49
# the shipID
# 5
# the depotID
# 5
# rec entire:
# 21
# sen entire:
# 5
# count
# 50
# the shipID
# 5
# the depotID
# 12
# rec entire:
# 21
# sen entire:
# 12
# count
# 51
# the shipID
# 5
# the depotID
# 5
# rec entire:
# 21
# sen entire:
# 5
# count
# 52
# the shipID
# 5
# the depotID
# 9
# rec entire:
# 21
# sen entire:
# 9
# count
# 53
# the shipID
# 5
# the depotID
# 5
# rec entire:
# 21
# sen entire:
# 5
# count
# 54
# the shipID
# 5
# the depotID
# 9
# rec entire:
# 21
# sen entire:
# 9
# count
# 55
# the shipID
# 5
# the depotID
# 5
# rec entire:
# 21
# sen entire:
# 5
# count
# 56
# the shipID
# 5
# the depotID
# 10
# rec entire:
# 21
# sen entire:
# 10
# count
# 57
# the shipID
# 5
# the depotID
# 10
# rec entire:
# 21
# sen entire:
# 10
# count
# 58
# the shipID
# 5
# the depotID
# 10
# rec entire:
# 21
# sen entire:
# 10
# count
# 59
# the shipID
# 6
# the depotID
# 9
# rec entire:
# 22
# sen entire:
# 9
# count
# 60
# the shipID
# 6
# the depotID
# 9
# rec entire:
# 22
# sen entire:
# 9
# count
# 61
# the shipID
# 6
# the depotID
# 9
# rec entire:
# 22
# sen entire:
# 9
# count
# 62
# the shipID
# 6
# the depotID
# 12
# rec entire:
# 22
# sen entire:
# 12
# count
# 63
# the shipID
# 6
# the depotID
# 10
# rec entire:
# 22
# sen entire:
# 10
# count
# 64
# the shipID
# 6
# the depotID
# 9
# rec entire:
# 22
# sen entire:
# 9
# count
# 65
# the shipID
# 6
# the depotID
# 9
# rec entire:
# 22
# sen entire:
# 9
# count
# 66
# the shipID
# 6
# the depotID
# 9
# rec entire:
# 22
# sen entire:
# 9
# count
# 67
# the shipID
# 6
# the depotID
# 12
# rec entire:
# 22
# sen entire:
# 12
# count
# 68
# the shipID
# 6
# the depotID
# 10
# rec entire:
# 22
# sen entire:
# 10
# count
# 69
# the shipID
# 6
# the depotID
# 9
# rec entire:
# 22
# sen entire:
# 9
# count
# 70
# the shipID
# 6
# the depotID
# 5
# rec entire:
# 22
# sen entire:
# 5
# count
# 71
# the shipID
# 7
# the depotID
# 12
# rec entire:
# 23
# sen entire:
# 12
# count
# 72
# the shipID
# 7
# the depotID
# 10
# rec entire:
# 23
# sen entire:
# 10
# count
# 73
# the shipID
# 7
# the depotID
# 9
# rec entire:
# 23
# sen entire:
# 9
# count
# 74
# the shipID
# 7
# the depotID
# 12
# rec entire:
# 23
# sen entire:
# 12
# count
# 75
# the shipID
# 7
# the depotID
# 12
# rec entire:
# 23
# sen entire:
# 12
# count
# 76
# the shipID
# 7
# the depotID
# 12
# rec entire:
# 23
# sen entire:
# 12
# count
# 77
# the shipID
# 7
# the depotID
# 5
# rec entire:
# 23
# sen entire:
# 5
# count
# 78
# the shipID
# 7
# the depotID
# 9
# rec entire:
# 23
# sen entire:
# 9
# count
# 79
# the shipID
# 7
# the depotID
# 5
# rec entire:
# 23
# sen entire:
# 5
# count
# 80
# the shipID
# 7
# the depotID
# 9
# rec entire:
# 23
# sen entire:
# 9
# count
# 81
# the shipID
# 7
# the depotID
# 10
# rec entire:
# 23
# sen entire:
# 10
# count
# 82
# the shipID
# 7
# the depotID
# 5
# rec entire:
# 23
# sen entire:
# 5
# count
# 83
# the shipID
# 8
# the depotID
# 12
# rec entire:
# 24
# sen entire:
# 12
# count
# 84
# the shipID
# 8
# the depotID
# 9
# rec entire:
# 24
# sen entire:
# 9
# count
# 85
# the shipID
# 8
# the depotID
# 9
# rec entire:
# 24
# sen entire:
# 9
# count
# 86
# the shipID
# 8
# the depotID
# 9
# rec entire:
# 24
# sen entire:
# 9
# count
# 87
# the shipID
# 8
# the depotID
# 1
# rec entire:
# 24
# sen entire:
# 1
# count
# 88
# the shipID
# 8
# the depotID
# 1
# rec entire:
# 24
# sen entire:
# 1
# count
# 89
# the shipID
# 8
# the depotID
# 9
# rec entire:
# 24
# sen entire:
# 9
# count
# 90
# the shipID
# 8
# the depotID
# 1
# rec entire:
# 24
# sen entire:
# 1
# count
# 91
# the shipID
# 8
# the depotID
# 9
# rec entire:
# 24
# sen entire:
# 9
# count
# 92
# the shipID
# 8
# the depotID
# 1
# rec entire:
# 24
# sen entire:
# 1
# count
# 93
# the shipID
# 8
# the depotID
# 1
# rec entire:
# 24
# sen entire:
# 1
# count
# 94
# the shipID
# 8
# the depotID
# 12
# rec entire:
# 24
# sen entire:
# 12
# count
# 95
# the shipID
# 8
# the depotID
# 1
# rec entire:
# 24
# sen entire:
# 1
# count
# 96
# the shipID
# 8
# the depotID
# 12
# rec entire:
# 24
# sen entire:
# 12
# count
# 97
# the shipID
# 8
# the depotID
# 1
# rec entire:
# 24
# sen entire:
# 1
# count
# 98
# the shipID
# 8
# the depotID
# 12
# rec entire:
# 24
# sen entire:
# 12
# count
# 99
# the shipID
# 9
# the depotID
# 4
# rec entire:
# 25
# sen entire:
# 4
# count
# 100
# the shipID
# 9
# the depotID
# 4
# rec entire:
# 25
# sen entire:
# 4
# count
# 101
# the shipID
# 9
# the depotID
# 12
# rec entire:
# 25
# sen entire:
# 12
# count
# 102
# the shipID
# 9
# the depotID
# 9
# rec entire:
# 25
# sen entire:
# 9
# count
# 103
# the shipID
# 9
# the depotID
# 10
# rec entire:
# 25
# sen entire:
# 10
# count
# 104
# the shipID
# 9
# the depotID
# 12
# rec entire:
# 25
# sen entire:
# 12
# count
# 105
# the shipID
# 9
# the depotID
# 4
# rec entire:
# 25
# sen entire:
# 4
# count
# 106
# the shipID
# 9
# the depotID
# 9
# rec entire:
# 25
# sen entire:
# 9
# count
# 107
# the shipID
# 9
# the depotID
# 10
# rec entire:
# 25
# sen entire:
# 10
# count
# 108
# the shipID
# 9
# the depotID
# 12
# rec entire:
# 25
# sen entire:
# 12
# count
# 109
# the shipID
# 9
# the depotID
# 9
# rec entire:
# 25
# sen entire:
# 9
# count
# 110
# the shipID
# 9
# the depotID
# 10
# rec entire:
# 25
# sen entire:
# 10
# count
# 111
# the shipID
# 9
# the depotID
# 4
# rec entire:
# 25
# sen entire:
# 4
# count
# 112
# the shipID
# 9
# the depotID
# 10
# rec entire:
# 25
# sen entire:
# 10
# count
# 113
# the shipID
# 9
# the depotID
# 10
# rec entire:
# 25
# sen entire:
# 10
# count
# 114
# the shipID
# 9
# the depotID
# 9
# rec entire:
# 25
# sen entire:
# 9
# count
# 115
# the shipID
# 9
# the depotID
# 10
# rec entire:
# 25
# sen entire:
# 10
# count
# 116
# the shipID
# 9
# the depotID
# 4
# rec entire:
# 25
# sen entire:
# 4
# count
# 117
# the shipID
# 9
# the depotID
# 4
# rec entire:
# 25
# sen entire:
# 4
# count
# 118
# the shipID
# 9
# the depotID
# 4
# rec entire:
# 25
# sen entire:
# 4
# count
# 119
# the shipID
# 10
# the depotID
# 4
# rec entire:
# 26
# sen entire:
# 4
# count
# 120
# the shipID
# 10
# the depotID
# 12
# rec entire:
# 26
# sen entire:
# 12
# count
# 121
# the shipID
# 10
# the depotID
# 4
# rec entire:
# 26
# sen entire:
# 4
# count
# 122
# the shipID
# 10
# the depotID
# 4
# rec entire:
# 26
# sen entire:
# 4
# count
# 123
# the shipID
# 10
# the depotID
# 12
# rec entire:
# 26
# sen entire:
# 12
# count
# 124
# the shipID
# 10
# the depotID
# 12
# rec entire:
# 26
# sen entire:
# 12
# count
# 125
# the shipID
# 10
# the depotID
# 4
# rec entire:
# 26
# sen entire:
# 4
# count
# 126
# the shipID
# 10
# the depotID
# 12
# rec entire:
# 26
# sen entire:
# 12
# count
# 127
# the shipID
# 10
# the depotID
# 12
# rec entire:
# 26
# sen entire:
# 12
# count
# 128
# the shipID
# 10
# the depotID
# 10
# rec entire:
# 26
# sen entire:
# 10
# count
# 129
# the shipID
# 10
# the depotID
# 10
# rec entire:
# 26
# sen entire:
# 10
# count
# 130
# the shipID
# 10
# the depotID
# 10
# rec entire:
# 26
# sen entire:
# 10
# count
# 131
# the shipID
# 10
# the depotID
# 4
# rec entire:
# 26
# sen entire:
# 4
# count
# 132
# the shipID
# 10
# the depotID
# 10
# rec entire:
# 26
# sen entire:
# 10
# count
# 133
# the shipID
# 10
# the depotID
# 4
# rec entire:
# 26
# sen entire:
# 4
# count
# 134
# the shipID
# 10
# the depotID
# 10
# rec entire:
# 26
# sen entire:
# 10
# count
# 135
# the shipID
# 10
# the depotID
# 9
# rec entire:
# 26
# sen entire:
# 9
# count
# 136
# the shipID
# 10
# the depotID
# 4
# rec entire:
# 26
# sen entire:
# 4
# count
# 137
# the shipID
# 10
# the depotID
# 9
# rec entire:
# 26
# sen entire:
# 9
# count
# 138
# the shipID
# 10
# the depotID
# 9
# rec entire:
# 26
# sen entire:
# 9
# count
# 139
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 140
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 141
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 142
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 143
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 144
# the shipID
# 11
# the depotID
# 12
# rec entire:
# 27
# sen entire:
# 12
# count
# 145
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 146
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 147
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 148
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 149
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 150
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 151
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 152
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 153
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 154
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 155
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 156
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 157
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 158
# the shipID
# 11
# the depotID
# 12
# rec entire:
# 27
# sen entire:
# 12
# count
# 159
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 160
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 161
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 162
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 163
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 164
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 165
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 166
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 167
# the shipID
# 11
# the depotID
# 12
# rec entire:
# 27
# sen entire:
# 12
# count
# 168
# the shipID
# 11
# the depotID
# 12
# rec entire:
# 27
# sen entire:
# 12
# count
# 169
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 170
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 171
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 172
# the shipID
# 11
# the depotID
# 12
# rec entire:
# 27
# sen entire:
# 12
# count
# 173
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 174
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 175
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 176
# the shipID
# 11
# the depotID
# 9
# rec entire:
# 27
# sen entire:
# 9
# count
# 177
# the shipID
# 11
# the depotID
# 4
# rec entire:
# 27
# sen entire:
# 4
# count
# 178
# the shipID
# 11
# the depotID
# 10
# rec entire:
# 27
# sen entire:
# 10
# count
# 179
# the shipID
# 12
# the depotID
# 10
# rec entire:
# 28
# sen entire:
# 10
# count
# 180
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 181
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 182
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 183
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 184
# the shipID
# 12
# the depotID
# 12
# rec entire:
# 28
# sen entire:
# 12
# count
# 185
# the shipID
# 12
# the depotID
# 10
# rec entire:
# 28
# sen entire:
# 10
# count
# 186
# the shipID
# 12
# the depotID
# 12
# rec entire:
# 28
# sen entire:
# 12
# count
# 187
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 188
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 189
# the shipID
# 12
# the depotID
# 12
# rec entire:
# 28
# sen entire:
# 12
# count
# 190
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 191
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 192
# the shipID
# 12
# the depotID
# 12
# rec entire:
# 28
# sen entire:
# 12
# count
# 193
# the shipID
# 12
# the depotID
# 12
# rec entire:
# 28
# sen entire:
# 12
# count
# 194
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 195
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 196
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 197
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 198
# the shipID
# 12
# the depotID
# 12
# rec entire:
# 28
# sen entire:
# 12
# count
# 199
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 200
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 201
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 202
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 203
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 204
# the shipID
# 12
# the depotID
# 10
# rec entire:
# 28
# sen entire:
# 10
# count
# 205
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 206
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 207
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 208
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 209
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 210
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 211
# the shipID
# 12
# the depotID
# 10
# rec entire:
# 28
# sen entire:
# 10
# count
# 212
# the shipID
# 12
# the depotID
# 10
# rec entire:
# 28
# sen entire:
# 10
# count
# 213
# the shipID
# 12
# the depotID
# 10
# rec entire:
# 28
# sen entire:
# 10
# count
# 214
# the shipID
# 12
# the depotID
# 9
# rec entire:
# 28
# sen entire:
# 9
# count
# 215
# the shipID
# 12
# the depotID
# 5
# rec entire:
# 28
# sen entire:
# 5
# count
# 216
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 217
# the shipID
# 13
# the depotID
# 12
# rec entire:
# 29
# sen entire:
# 12
# count
# 218
# the shipID
# 13
# the depotID
# 12
# rec entire:
# 29
# sen entire:
# 12
# count
# 219
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 220
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 221
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 222
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 223
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 224
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 225
# the shipID
# 13
# the depotID
# 12
# rec entire:
# 29
# sen entire:
# 12
# count
# 226
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 227
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 228
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 229
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 230
# the shipID
# 13
# the depotID
# 12
# rec entire:
# 29
# sen entire:
# 12
# count
# 231
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 232
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 233
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 234
# the shipID
# 13
# the depotID
# 12
# rec entire:
# 29
# sen entire:
# 12
# count
# 235
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 236
# the shipID
# 13
# the depotID
# 12
# rec entire:
# 29
# sen entire:
# 12
# count
# 237
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 238
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 239
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 240
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 241
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 242
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 243
# the shipID
# 13
# the depotID
# 10
# rec entire:
# 29
# sen entire:
# 10
# count
# 244
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 245
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 246
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 247
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 248
# the shipID
# 13
# the depotID
# 12
# rec entire:
# 29
# sen entire:
# 12
# count
# 249
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 250
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 251
# the shipID
# 13
# the depotID
# 5
# rec entire:
# 29
# sen entire:
# 5
# count
# 252
# the shipID
# 13
# the depotID
# 9
# rec entire:
# 29
# sen entire:
# 9
# count
# 253
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 254
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 255
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 256
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 257
# the shipID
# 14
# the depotID
# 9
# rec entire:
# 30
# sen entire:
# 9
# count
# 258
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 259
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 260
# the shipID
# 14
# the depotID
# 9
# rec entire:
# 30
# sen entire:
# 9
# count
# 261
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 262
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 263
# the shipID
# 14
# the depotID
# 9
# rec entire:
# 30
# sen entire:
# 9
# count
# 264
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 265
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 266
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 267
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 268
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 269
# the shipID
# 14
# the depotID
# 12
# rec entire:
# 30
# sen entire:
# 12
# count
# 270
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 271
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 272
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 273
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 274
# the shipID
# 14
# the depotID
# 9
# rec entire:
# 30
# sen entire:
# 9
# count
# 275
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 276
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 277
# the shipID
# 14
# the depotID
# 12
# rec entire:
# 30
# sen entire:
# 12
# count
# 278
# the shipID
# 14
# the depotID
# 9
# rec entire:
# 30
# sen entire:
# 9
# count
# 279
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 280
# the shipID
# 14
# the depotID
# 12
# rec entire:
# 30
# sen entire:
# 12
# count
# 281
# the shipID
# 14
# the depotID
# 5
# rec entire:
# 30
# sen entire:
# 5
# count
# 282
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 283
# the shipID
# 14
# the depotID
# 9
# rec entire:
# 30
# sen entire:
# 9
# count
# 284
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 285
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 286
# the shipID
# 14
# the depotID
# 9
# rec entire:
# 30
# sen entire:
# 9
# count
# 287
# the shipID
# 14
# the depotID
# 12
# rec entire:
# 30
# sen entire:
# 12
# count
# 288
# the shipID
# 14
# the depotID
# 10
# rec entire:
# 30
# sen entire:
# 10
# count
# 289
# the shipID
# 14
# the depotID
# 12
# rec entire:
# 30
# sen entire:
# 12
# count
# 290
# the shipID
# 15
# the depotID
# 9
# rec entire:
# 31
# sen entire:
# 9
# count
# 291
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 292
# the shipID
# 15
# the depotID
# 12
# rec entire:
# 31
# sen entire:
# 12
# count
# 293
# the shipID
# 15
# the depotID
# 12
# rec entire:
# 31
# sen entire:
# 12
# count
# 294
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 295
# the shipID
# 15
# the depotID
# 12
# rec entire:
# 31
# sen entire:
# 12
# count
# 296
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 297
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 298
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 299
# the shipID
# 15
# the depotID
# 12
# rec entire:
# 31
# sen entire:
# 12
# count
# 300
# the shipID
# 15
# the depotID
# 9
# rec entire:
# 31
# sen entire:
# 9
# count
# 301
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 302
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 303
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 304
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 305
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 306
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 307
# the shipID
# 15
# the depotID
# 9
# rec entire:
# 31
# sen entire:
# 9
# count
# 308
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 309
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 310
# the shipID
# 15
# the depotID
# 12
# rec entire:
# 31
# sen entire:
# 12
# count
# 311
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 312
# the shipID
# 15
# the depotID
# 9
# rec entire:
# 31
# sen entire:
# 9
# count
# 313
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 314
# the shipID
# 15
# the depotID
# 12
# rec entire:
# 31
# sen entire:
# 12
# count
# 315
# the shipID
# 15
# the depotID
# 9
# rec entire:
# 31
# sen entire:
# 9
# count
# 316
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 317
# the shipID
# 15
# the depotID
# 12
# rec entire:
# 31
# sen entire:
# 12
# count
# 318
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 319
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 320
# the shipID
# 15
# the depotID
# 9
# rec entire:
# 31
# sen entire:
# 9
# count
# 321
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 322
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 323
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 324
# the shipID
# 15
# the depotID
# 10
# rec entire:
# 31
# sen entire:
# 10
# count
# 325
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 326
# the shipID
# 15
# the depotID
# 5
# rec entire:
# 31
# sen entire:
# 5
# count
# 327
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 328
# the shipID
# 16
# the depotID
# 12
# rec entire:
# 32
# sen entire:
# 12
# count
# 329
# the shipID
# 16
# the depotID
# 10
# rec entire:
# 32
# sen entire:
# 10
# count
# 330
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 331
# the shipID
# 16
# the depotID
# 9
# rec entire:
# 32
# sen entire:
# 9
# count
# 332
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 333
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 334
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 335
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 336
# the shipID
# 16
# the depotID
# 12
# rec entire:
# 32
# sen entire:
# 12
# count
# 337
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 338
# the shipID
# 16
# the depotID
# 9
# rec entire:
# 32
# sen entire:
# 9
# count
# 339
# the shipID
# 16
# the depotID
# 12
# rec entire:
# 32
# sen entire:
# 12
# count
# 340
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 341
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 342
# the shipID
# 16
# the depotID
# 10
# rec entire:
# 32
# sen entire:
# 10
# count
# 343
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 344
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 345
# the shipID
# 16
# the depotID
# 9
# rec entire:
# 32
# sen entire:
# 9
# count
# 346
# the shipID
# 16
# the depotID
# 9
# rec entire:
# 32
# sen entire:
# 9
# count
# 347
# the shipID
# 16
# the depotID
# 10
# rec entire:
# 32
# sen entire:
# 10
# count
# 348
# the shipID
# 16
# the depotID
# 10
# rec entire:
# 32
# sen entire:
# 10
# count
# 349
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 350
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 351
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 352
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 353
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 354
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 355
# the shipID
# 16
# the depotID
# 9
# rec entire:
# 32
# sen entire:
# 9
# count
# 356
# the shipID
# 16
# the depotID
# 12
# rec entire:
# 32
# sen entire:
# 12
# count
# 357
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 358
# the shipID
# 16
# the depotID
# 9
# rec entire:
# 32
# sen entire:
# 9
# count
# 359
# the shipID
# 16
# the depotID
# 5
# rec entire:
# 32
# sen entire:
# 5
# count
# 360
# the shipID
# 16
# the depotID
# 12
# rec entire:
# 32
# sen entire:
# 12
# count
# 361
# the shipID
# 16
# the depotID
# 12
# rec entire:
# 32
# sen entire:
# 12
# count
# 362
# the shipID
# 16
# the depotID
# 9
# rec entire:
# 32
# sen entire:
# 9
# count
# 363
# the shipID
# 16
# the depotID
# 12
# rec entire:
# 32
# sen entire:
# 12
# count
# 364
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 365
# the shipID
# 17
# the depotID
# 9
# rec entire:
# 33
# sen entire:
# 9
# count
# 366
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 367
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 368
# the shipID
# 17
# the depotID
# 9
# rec entire:
# 33
# sen entire:
# 9
# count
# 369
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 370
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 371
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 372
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 373
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 374
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 375
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 376
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 377
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 378
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 379
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 380
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 381
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 382
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 383
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 384
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 385
# the shipID
# 17
# the depotID
# 9
# rec entire:
# 33
# sen entire:
# 9
# count
# 386
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 387
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 388
# the shipID
# 17
# the depotID
# 9
# rec entire:
# 33
# sen entire:
# 9
# count
# 389
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 390
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 391
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 392
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 393
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 394
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 395
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 396
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 397
# the shipID
# 17
# the depotID
# 10
# rec entire:
# 33
# sen entire:
# 10
# count
# 398
# the shipID
# 17
# the depotID
# 9
# rec entire:
# 33
# sen entire:
# 9
# count
# 399
# the shipID
# 17
# the depotID
# 12
# rec entire:
# 33
# sen entire:
# 12
# count
# 400
# the shipID
# 17
# the depotID
# 5
# rec entire:
# 33
# sen entire:
# 5
# count
# 401
# the shipID
# 18
# the depotID
# 3
# rec entire:
# 34
# sen entire:
# 3
# count
# 402
# the shipID
# 18
# the depotID
# 3
# rec entire:
# 34
# sen entire:
# 3
# count
# 403
# the shipID
# 18
# the depotID
# 12
# rec entire:
# 34
# sen entire:
# 12
# count
# 404
# the shipID
# 18
# the depotID
# 3
# rec entire:
# 34
# sen entire:
# 3
# count
# 405
# the shipID
# 18
# the depotID
# 9
# rec entire:
# 34
# sen entire:
# 9
# count
# 406
# the shipID
# 18
# the depotID
# 9
# rec entire:
# 34
# sen entire:
# 9
# count
# 407
# the shipID
# 18
# the depotID
# 12
# rec entire:
# 34
# sen entire:
# 12
# count
# 408
# the shipID
# 18
# the depotID
# 12
# rec entire:
# 34
# sen entire:
# 12
# count
# 409
# the shipID
# 18
# the depotID
# 3
# rec entire:
# 34
# sen entire:
# 3
# count
# 410
# the shipID
# 18
# the depotID
# 3
# rec entire:
# 34
# sen entire:
# 3
# count
# 411
# the shipID
# 18
# the depotID
# 12
# rec entire:
# 34
# sen entire:
# 12
# count
# 412
# the shipID
# 18
# the depotID
# 9
# rec entire:
# 34
# sen entire:
# 9
# count
# 413
# the shipID
# 19
# the depotID
# 9
# rec entire:
# 35
# sen entire:
# 9
# count
# 414
# the shipID
# 19
# the depotID
# 10
# rec entire:
# 35
# sen entire:
# 10
# count
# 415
# the shipID
# 19
# the depotID
# 9
# rec entire:
# 35
# sen entire:
# 9
# count
# 416
# the shipID
# 19
# the depotID
# 3
# rec entire:
# 35
# sen entire:
# 3
# count
# 417
# the shipID
# 19
# the depotID
# 9
# rec entire:
# 35
# sen entire:
# 9
# count
# 418
# the shipID
# 19
# the depotID
# 12
# rec entire:
# 35
# sen entire:
# 12
# count
# 419
# the shipID
# 19
# the depotID
# 12
# rec entire:
# 35
# sen entire:
# 12
# count
# 420
# the shipID
# 19
# the depotID
# 9
# rec entire:
# 35
# sen entire:
# 9
# count
# 421
# the shipID
# 19
# the depotID
# 12
# rec entire:
# 35
# sen entire:
# 12
# count
# 422
# the shipID
# 19
# the depotID
# 3
# rec entire:
# 35
# sen entire:
# 3
# count
# 423
# the shipID
# 19
# the depotID
# 10
# rec entire:
# 35
# sen entire:
# 10
# count
# 424
# the shipID
# 19
# the depotID
# 3
# rec entire:
# 35
# sen entire:
# 3
# count
# 425
# the shipID
# 20
# the depotID
# 10
# rec entire:
# 36
# sen entire:
# 10
# count
# 426
# the shipID
# 20
# the depotID
# 9
# rec entire:
# 36
# sen entire:
# 9
# count
# 427
# the shipID
# 20
# the depotID
# 3
# rec entire:
# 36
# sen entire:
# 3
# count
# 428
# the shipID
# 20
# the depotID
# 3
# rec entire:
# 36
# sen entire:
# 3
# count
# 429
# the shipID
# 20
# the depotID
# 10
# rec entire:
# 36
# sen entire:
# 10
# count
# 430
# the shipID
# 20
# the depotID
# 12
# rec entire:
# 36
# sen entire:
# 12
# count
# 431
# the shipID
# 20
# the depotID
# 10
# rec entire:
# 36
# sen entire:
# 10
# count
# 432
# the shipID
# 20
# the depotID
# 3
# rec entire:
# 36
# sen entire:
# 3
# count
# 433
# the shipID
# 20
# the depotID
# 12
# rec entire:
# 36
# sen entire:
# 12
# count
# 434
# the shipID
# 20
# the depotID
# 12
# rec entire:
# 36
# sen entire:
# 12
# count
# 435
# the shipID
# 20
# the depotID
# 3
# rec entire:
# 36
# sen entire:
# 3
# count
# 436
# the shipID
# 20
# the depotID
# 12
# rec entire:
# 36
# sen entire:
# 12
# count
# 437
# the shipID
# 21
# the depotID
# 14
# rec entire:
# 37
# sen entire:
# 14
# count
# 438
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 439
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 440
# the shipID
# 21
# the depotID
# 14
# rec entire:
# 37
# sen entire:
# 14
# count
# 441
# the shipID
# 21
# the depotID
# 10
# rec entire:
# 37
# sen entire:
# 10
# count
# 442
# the shipID
# 21
# the depotID
# 14
# rec entire:
# 37
# sen entire:
# 14
# count
# 443
# the shipID
# 21
# the depotID
# 9
# rec entire:
# 37
# sen entire:
# 9
# count
# 444
# the shipID
# 21
# the depotID
# 10
# rec entire:
# 37
# sen entire:
# 10
# count
# 445
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 446
# the shipID
# 21
# the depotID
# 10
# rec entire:
# 37
# sen entire:
# 10
# count
# 447
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 448
# the shipID
# 21
# the depotID
# 10
# rec entire:
# 37
# sen entire:
# 10
# count
# 449
# the shipID
# 21
# the depotID
# 9
# rec entire:
# 37
# sen entire:
# 9
# count
# 450
# the shipID
# 21
# the depotID
# 10
# rec entire:
# 37
# sen entire:
# 10
# count
# 451
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 452
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 453
# the shipID
# 21
# the depotID
# 14
# rec entire:
# 37
# sen entire:
# 14
# count
# 454
# the shipID
# 21
# the depotID
# 14
# rec entire:
# 37
# sen entire:
# 14
# count
# 455
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 456
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 457
# the shipID
# 21
# the depotID
# 10
# rec entire:
# 37
# sen entire:
# 10
# count
# 458
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 459
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 460
# the shipID
# 21
# the depotID
# 9
# rec entire:
# 37
# sen entire:
# 9
# count
# 461
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 462
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 463
# the shipID
# 21
# the depotID
# 9
# rec entire:
# 37
# sen entire:
# 9
# count
# 464
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 465
# the shipID
# 21
# the depotID
# 14
# rec entire:
# 37
# sen entire:
# 14
# count
# 466
# the shipID
# 21
# the depotID
# 5
# rec entire:
# 37
# sen entire:
# 5
# count
# 467
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 468
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 469
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 470
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 471
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 472
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 473
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 474
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 475
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 476
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 477
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 478
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 479
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 480
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 481
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 482
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 483
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 484
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 485
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 486
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 487
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 488
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 489
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 490
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 491
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 492
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 493
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 494
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 495
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 496
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 497
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 498
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 499
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 500
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 501
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 502
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 503
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 504
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 505
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 506
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 507
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 508
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 509
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 510
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 511
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 512
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 513
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 514
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 515
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 516
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 517
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 518
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 519
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 520
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 521
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 522
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 523
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 524
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 525
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 526
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 527
# the shipID
# 22
# the depotID
# 10
# rec entire:
# 38
# sen entire:
# 10
# count
# 528
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 529
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 530
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 531
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 532
# the shipID
# 22
# the depotID
# 9
# rec entire:
# 38
# sen entire:
# 9
# count
# 533
# the shipID
# 22
# the depotID
# 12
# rec entire:
# 38
# sen entire:
# 12
# count
# 534
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 535
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 536
# the shipID
# 22
# the depotID
# 2
# rec entire:
# 38
# sen entire:
# 2
# count
# 537
# the shipID
# 23
# the depotID
# 9
# rec entire:
# 39
# sen entire:
# 9
# count
# 538
# the shipID
# 23
# the depotID
# 12
# rec entire:
# 39
# sen entire:
# 12
# count
# 539
# the shipID
# 23
# the depotID
# 2
# rec entire:
# 39
# sen entire:
# 2
# count
# 540
# the shipID
# 23
# the depotID
# 2
# rec entire:
# 39
# sen entire:
# 2
# count
# 541
# the shipID
# 23
# the depotID
# 2
# rec entire:
# 39
# sen entire:
# 2
# count
# 542
# the shipID
# 23
# the depotID
# 9
# rec entire:
# 39
# sen entire:
# 9
# count
# 543
# the shipID
# 23
# the depotID
# 2
# rec entire:
# 39
# sen entire:
# 2
# count
# 544
# the shipID
# 23
# the depotID
# 10
# rec entire:
# 39
# sen entire:
# 10
# count
# 545
# the shipID
# 23
# the depotID
# 2
# rec entire:
# 39
# sen entire:
# 2
# count
# 546
# the shipID
# 23
# the depotID
# 12
# rec entire:
# 39
# sen entire:
# 12
# count
# 547
# the shipID
# 23
# the depotID
# 12
# rec entire:
# 39
# sen entire:
# 12
# count
# 548
# the shipID
# 23
# the depotID
# 12
# rec entire:
# 39
# sen entire:
# 12
# count
# 549
# the shipID
# 23
# the depotID
# 2
# rec entire:
# 39
# sen entire:
# 2
# count
# 550
# the shipID
# 23
# the depotID
# 2
# rec entire:
# 39
# sen entire:
# 2
# count
# 551
# the shipID
# 23
# the depotID
# 12
# rec entire:
# 39
# sen entire:
# 12
# count
# 552
# the shipID
# 24
# the depotID
# 10
# rec entire:
# 40
# sen entire:
# 10
# count
# 553
# the shipID
# 24
# the depotID
# 9
# rec entire:
# 40
# sen entire:
# 9
# count
# 554
# the shipID
# 24
# the depotID
# 10
# rec entire:
# 40
# sen entire:
# 10
# count
# 555
# the shipID
# 24
# the depotID
# 3
# rec entire:
# 40
# sen entire:
# 3
# count
# 556
# the shipID
# 24
# the depotID
# 3
# rec entire:
# 40
# sen entire:
# 3
# count
# 557
# the shipID
# 24
# the depotID
# 3
# rec entire:
# 40
# sen entire:
# 3
# count
# 558
# the shipID
# 24
# the depotID
# 3
# rec entire:
# 40
# sen entire:
# 3
# count
# 559
# the shipID
# 24
# the depotID
# 3
# rec entire:
# 40
# sen entire:
# 3
# count
# 560
# the shipID
# 24
# the depotID
# 10
# rec entire:
# 40
# sen entire:
# 10
# count
# 561
# the shipID
# 24
# the depotID
# 12
# rec entire:
# 40
# sen entire:
# 12
# count
# 562
# the shipID
# 24
# the depotID
# 9
# rec entire:
# 40
# sen entire:
# 9
# count
# 563
# the shipID
# 24
# the depotID
# 12
# rec entire:
# 40
# sen entire:
# 12
# count
# 564
# the shipID
# 25
# the depotID
# 12
# rec entire:
# 41
# sen entire:
# 12
# count
# 565
# the shipID
# 25
# the depotID
# 3
# rec entire:
# 41
# sen entire:
# 3
# count
# 566
# the shipID
# 25
# the depotID
# 9
# rec entire:
# 41
# sen entire:
# 9
# count
# 567
# the shipID
# 25
# the depotID
# 9
# rec entire:
# 41
# sen entire:
# 9
# count
# 568
# the shipID
# 25
# the depotID
# 3
# rec entire:
# 41
# sen entire:
# 3
# count
# 569
# the shipID
# 25
# the depotID
# 12
# rec entire:
# 41
# sen entire:
# 12
# count
# 570
# the shipID
# 25
# the depotID
# 9
# rec entire:
# 41
# sen entire:
# 9
# count
# 571
# the shipID
# 25
# the depotID
# 10
# rec entire:
# 41
# sen entire:
# 10
# count
# 572
# the shipID
# 25
# the depotID
# 9
# rec entire:
# 41
# sen entire:
# 9
# count
# 573
# the shipID
# 25
# the depotID
# 9
# rec entire:
# 41
# sen entire:
# 9
# count
# 574
# the shipID
# 25
# the depotID
# 9
# rec entire:
# 41
# sen entire:
# 9
# count
# 575
# the shipID
# 25
# the depotID
# 9
# rec entire:
# 41
# sen entire:
# 9
# count
# 576
# the shipID
# 25
# the depotID
# 3
# rec entire:
# 41
# sen entire:
# 3
# count
# 577
# the shipID
# 25
# the depotID
# 10
# rec entire:
# 41
# sen entire:
# 10
# count
# 578
# the shipID
# 25
# the depotID
# 10
# rec entire:
# 41
# sen entire:
# 10
# count
# 579
# the shipID
# 25
# the depotID
# 3
# rec entire:
# 41
# sen entire:
# 3
# count
# 580
# the shipID
# 25
# the depotID
# 3
# rec entire:
# 41
# sen entire:
# 3
# count
# 581
# the shipID
# 25
# the depotID
# 12
# rec entire:
# 41
# sen entire:
# 12
# count
# 582
# the shipID
# 25
# the depotID
# 12
# rec entire:
# 41
# sen entire:
# 12
# count
# 583
# the shipID
# 25
# the depotID
# 10
# rec entire:
# 41
# sen entire:
# 10
# count
# 584
# the shipID
# 26
# the depotID
# 14
# rec entire:
# 42
# sen entire:
# 14
# count
# 585
# the shipID
# 26
# the depotID
# 9
# rec entire:
# 42
# sen entire:
# 9
# count
# 586
# the shipID
# 26
# the depotID
# 10
# rec entire:
# 42
# sen entire:
# 10
# count
# 587
# the shipID
# 26
# the depotID
# 9
# rec entire:
# 42
# sen entire:
# 9
# count
# 588
# the shipID
# 26
# the depotID
# 14
# rec entire:
# 42
# sen entire:
# 14
# count
# 589
# the shipID
# 26
# the depotID
# 3
# rec entire:
# 42
# sen entire:
# 3
# count
# 590
# the shipID
# 26
# the depotID
# 10
# rec entire:
# 42
# sen entire:
# 10
# count
# 591
# the shipID
# 26
# the depotID
# 9
# rec entire:
# 42
# sen entire:
# 9
# count
# 592
# the shipID
# 26
# the depotID
# 10
# rec entire:
# 42
# sen entire:
# 10
# count
# 593
# the shipID
# 26
# the depotID
# 3
# rec entire:
# 42
# sen entire:
# 3
# count
# 594
# the shipID
# 26
# the depotID
# 10
# rec entire:
# 42
# sen entire:
# 10
# count
# 595
# the shipID
# 26
# the depotID
# 14
# rec entire:
# 42
# sen entire:
# 14
# count
# 596
# the shipID
# 27
# the depotID
# 3
# rec entire:
# 43
# sen entire:
# 3
# count
# 597
# the shipID
# 27
# the depotID
# 14
# rec entire:
# 43
# sen entire:
# 14
# count
# 598
# the shipID
# 27
# the depotID
# 9
# rec entire:
# 43
# sen entire:
# 9
# count
# 599
# the shipID
# 27
# the depotID
# 14
# rec entire:
# 43
# sen entire:
# 14
# count
# 600
# the shipID
# 27
# the depotID
# 9
# rec entire:
# 43
# sen entire:
# 9
# count
# 601
# the shipID
# 27
# the depotID
# 3
# rec entire:
# 43
# sen entire:
# 3
# count
# 602
# the shipID
# 27
# the depotID
# 3
# rec entire:
# 43
# sen entire:
# 3
# count
# 603
# the shipID
# 27
# the depotID
# 9
# rec entire:
# 43
# sen entire:
# 9
# count
# 604
# the shipID
# 27
# the depotID
# 3
# rec entire:
# 43
# sen entire:
# 3
# count
# 605
# the shipID
# 27
# the depotID
# 14
# rec entire:
# 43
# sen entire:
# 14
# count
# 606
# the shipID
# 27
# the depotID
# 3
# rec entire:
# 43
# sen entire:
# 3
# count
# 607
# the shipID
# 27
# the depotID
# 14
# rec entire:
# 43
# sen entire:
# 14
# count
# 608
# the shipID
# 28
# the depotID
# 12
# rec entire:
# 44
# sen entire:
# 12
# count
# 609
# the shipID
# 28
# the depotID
# 3
# rec entire:
# 44
# sen entire:
# 3
# count
# 610
# the shipID
# 28
# the depotID
# 10
# rec entire:
# 44
# sen entire:
# 10
# count
# 611
# the shipID
# 28
# the depotID
# 9
# rec entire:
# 44
# sen entire:
# 9
# count
# 612
# the shipID
# 28
# the depotID
# 3
# rec entire:
# 44
# sen entire:
# 3
# count
# 613
# the shipID
# 28
# the depotID
# 9
# rec entire:
# 44
# sen entire:
# 9
# count
# 614
# the shipID
# 28
# the depotID
# 9
# rec entire:
# 44
# sen entire:
# 9
# count
# 615
# the shipID
# 28
# the depotID
# 9
# rec entire:
# 44
# sen entire:
# 9
# count
# 616
# the shipID
# 28
# the depotID
# 12
# rec entire:
# 44
# sen entire:
# 12
# count
# 617
# the shipID
# 28
# the depotID
# 10
# rec entire:
# 44
# sen entire:
# 10
# count
# 618
# the shipID
# 28
# the depotID
# 9
# rec entire:
# 44
# sen entire:
# 9
# count
# 619
# the shipID
# 28
# the depotID
# 3
# rec entire:
# 44
# sen entire:
# 3
# count
# 620
# the shipID
# 28
# the depotID
# 12
# rec entire:
# 44
# sen entire:
# 12
# count
# 621
# the shipID
# 28
# the depotID
# 12
# rec entire:
# 44
# sen entire:
# 12
# count
# 622
# the shipID
# 28
# the depotID
# 3
# rec entire:
# 44
# sen entire:
# 3
# count
# 623
# the shipID
# 28
# the depotID
# 12
# rec entire:
# 44
# sen entire:
# 12
# count
# 624
# the shipID
# 28
# the depotID
# 9
# rec entire:
# 44
# sen entire:
# 9
# count
# 625
# the shipID
# 28
# the depotID
# 3
# rec entire:
# 44
# sen entire:
# 3
# count
# 626
# the shipID
# 28
# the depotID
# 9
# rec entire:
# 44
# sen entire:
# 9
# count
# 627
# the shipID
# 28
# the depotID
# 3
# rec entire:
# 44
# sen entire:
# 3
# count
# 628
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 629
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 630
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 631
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 632
# the shipID
# 29
# the depotID
# 14
# rec entire:
# 45
# sen entire:
# 14
# count
# 633
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 634
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 635
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 636
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 637
# the shipID
# 29
# the depotID
# 10
# rec entire:
# 45
# sen entire:
# 10
# count
# 638
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 639
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 640
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 641
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 642
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 643
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 644
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 645
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 646
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 647
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 648
# the shipID
# 29
# the depotID
# 14
# rec entire:
# 45
# sen entire:
# 14
# count
# 649
# the shipID
# 29
# the depotID
# 14
# rec entire:
# 45
# sen entire:
# 14
# count
# 650
# the shipID
# 29
# the depotID
# 10
# rec entire:
# 45
# sen entire:
# 10
# count
# 651
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 652
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 653
# the shipID
# 29
# the depotID
# 14
# rec entire:
# 45
# sen entire:
# 14
# count
# 654
# the shipID
# 29
# the depotID
# 14
# rec entire:
# 45
# sen entire:
# 14
# count
# 655
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 656
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 657
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 658
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 659
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 660
# the shipID
# 29
# the depotID
# 9
# rec entire:
# 45
# sen entire:
# 9
# count
# 661
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 662
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 663
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 664
# the shipID
# 29
# the depotID
# 5
# rec entire:
# 45
# sen entire:
# 5
# count
# 665
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 666
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 667
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 668
# the shipID
# 30
# the depotID
# 14
# rec entire:
# 46
# sen entire:
# 14
# count
# 669
# the shipID
# 30
# the depotID
# 14
# rec entire:
# 46
# sen entire:
# 14
# count
# 670
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 671
# the shipID
# 30
# the depotID
# 9
# rec entire:
# 46
# sen entire:
# 9
# count
# 672
# the shipID
# 30
# the depotID
# 14
# rec entire:
# 46
# sen entire:
# 14
# count
# 673
# the shipID
# 30
# the depotID
# 9
# rec entire:
# 46
# sen entire:
# 9
# count
# 674
# the shipID
# 30
# the depotID
# 9
# rec entire:
# 46
# sen entire:
# 9
# count
# 675
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 676
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 677
# the shipID
# 30
# the depotID
# 14
# rec entire:
# 46
# sen entire:
# 14
# count
# 678
# the shipID
# 30
# the depotID
# 9
# rec entire:
# 46
# sen entire:
# 9
# count
# 679
# the shipID
# 30
# the depotID
# 14
# rec entire:
# 46
# sen entire:
# 14
# count
# 680
# the shipID
# 30
# the depotID
# 14
# rec entire:
# 46
# sen entire:
# 14
# count
# 681
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 682
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 683
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 684
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 685
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 686
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 687
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 688
# the shipID
# 30
# the depotID
# 9
# rec entire:
# 46
# sen entire:
# 9
# count
# 689
# the shipID
# 30
# the depotID
# 14
# rec entire:
# 46
# sen entire:
# 14
# count
# 690
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 691
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 692
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 693
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 694
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 695
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 696
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 697
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 698
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 699
# the shipID
# 30
# the depotID
# 10
# rec entire:
# 46
# sen entire:
# 10
# count
# 700
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 701
# the shipID
# 30
# the depotID
# 5
# rec entire:
# 46
# sen entire:
# 5
# count
# 702
# the shipID
# 31
# the depotID
# 14
# rec entire:
# 47
# sen entire:
# 14
# count
# 703
# the shipID
# 31
# the depotID
# 10
# rec entire:
# 47
# sen entire:
# 10
# count
# 704
# the shipID
# 31
# the depotID
# 10
# rec entire:
# 47
# sen entire:
# 10
# count
# 705
# the shipID
# 31
# the depotID
# 5
# rec entire:
# 47
# sen entire:
# 5
# count
# 706
# the shipID
# 31
# the depotID
# 5
# rec entire:
# 47
# sen entire:
# 5
# count
# 707
# the shipID
# 31
# the depotID
# 5
# rec entire:
# 47
# sen entire:
# 5
# count
# 708
# the shipID
# 31
# the depotID
# 14
# rec entire:
# 47
# sen entire:
# 14
# count
# 709
# the shipID
# 31
# the depotID
# 5
# rec entire:
# 47
# sen entire:
# 5
# count
# 710
# the shipID
# 31
# the depotID
# 5
# ...
# 7
# count
# 6910
# the shipID
# 343
# the depotID
# 7
# rec entire:
# 359
# sen entire:
# 7
# count
# 6911
# the shipID
# 343
# the depotID
# 10
# rec entire:
# 359
# sen entire:
# 10
# count
# 6912
# the shipID
# 343
# the depotID
# 10
# rec entire:
# 359
# sen entire:
# 10
# count
# 6913
# the shipID
# 343
# the depotID
# 7
# rec entire:
# 359
# sen entire:
# 7
# count
# 6914
# the shipID
# 343
# the depotID
# 14
# rec entire:
# 359
# sen entire:
# 14
# count
# 6915
# the shipID
# 343
# the depotID
# 10
# rec entire:
# 359
# sen entire:
# 10
# count
# 6916
# the shipID
# 343
# the depotID
# 10
# rec entire:
# 359
# sen entire:
# 10
# count
# 6917
# the shipID
# 344
# the depotID
# 9
# rec entire:
# 360
# sen entire:
# 9
# count
# 6918
# the shipID
# 344
# the depotID
# 9
# rec entire:
# 360
# sen entire:
# 9
# count
# 6919
# the shipID
# 344
# the depotID
# 10
# rec entire:
# 360
# sen entire:
# 10
# count
# 6920
# the shipID
# 344
# the depotID
# 10
# rec entire:
# 360
# sen entire:
# 10
# count
# 6921
# the shipID
# 344
# the depotID
# 11
# rec entire:
# 360
# sen entire:
# 11
# count
# 6922
# the shipID
# 344
# the depotID
# 11
# rec entire:
# 360
# sen entire:
# 11
# count
# 6923
# the shipID
# 344
# the depotID
# 9
# rec entire:
# 360
# sen entire:
# 9
# count
# 6924
# the shipID
# 344
# the depotID
# 10
# rec entire:
# 360
# sen entire:
# 10
# count
# 6925
# the shipID
# 344
# the depotID
# 9
# rec entire:
# 360
# sen entire:
# 9
# count
# 6926
# the shipID
# 344
# the depotID
# 5
# rec entire:
# 360
# sen entire:
# 5
# count
# 6927
# the shipID
# 344
# the depotID
# 10
# rec entire:
# 360
# sen entire:
# 10
# count
# 6928
# the shipID
# 344
# the depotID
# 5
# rec entire:
# 360
# sen entire:
# 5
# count
# 6929
# the shipID
# 344
# the depotID
# 5
# rec entire:
# 360
# sen entire:
# 5
# count
# 6930
# the shipID
# 344
# the depotID
# 9
# rec entire:
# 360
# sen entire:
# 9
# count
# 6931
# the shipID
# 345
# the depotID
# 10
# rec entire:
# 361
# sen entire:
# 10
# count
# 6932
# the shipID
# 345
# the depotID
# 10
# rec entire:
# 361
# sen entire:
# 10
# count
# 6933
# the shipID
# 345
# the depotID
# 9
# rec entire:
# 361
# sen entire:
# 9
# count
# 6934
# the shipID
# 345
# the depotID
# 2
# rec entire:
# 361
# sen entire:
# 2
# count
# 6935
# the shipID
# 345
# the depotID
# 9
# rec entire:
# 361
# sen entire:
# 9
# count
# 6936
# the shipID
# 345
# the depotID
# 2
# rec entire:
# 361
# sen entire:
# 2
# count
# 6937
# the shipID
# 345
# the depotID
# 10
# rec entire:
# 361
# sen entire:
# 10
# count
# 6938
# the shipID
# 345
# the depotID
# 2
# rec entire:
# 361
# sen entire:
# 2
# count
# 6939
# the shipID
# 345
# the depotID
# 2
# rec entire:
# 361
# sen entire:
# 2
# count
# 6940
# the shipID
# 345
# the depotID
# 2
# rec entire:
# 361
# sen entire:
# 2
# count
# 6941
# the shipID
# 345
# the depotID
# 10
# rec entire:
# 361
# sen entire:
# 10
# count
# 6942
# the shipID
# 346
# the depotID
# 9
# rec entire:
# 362
# sen entire:
# 9
# count
# 6943
# the shipID
# 346
# the depotID
# 14
# rec entire:
# 362
# sen entire:
# 14
# count
# 6944
# the shipID
# 346
# the depotID
# 6
# rec entire:
# 362
# sen entire:
# 6
# count
# 6945
# the shipID
# 346
# the depotID
# 9
# rec entire:
# 362
# sen entire:
# 9
# count
# 6946
# the shipID
# 346
# the depotID
# 10
# rec entire:
# 362
# sen entire:
# 10
# count
# 6947
# the shipID
# 346
# the depotID
# 6
# rec entire:
# 362
# sen entire:
# 6
# count
# 6948
# the shipID
# 346
# the depotID
# 6
# rec entire:
# 362
# sen entire:
# 6
# count
# 6949
# the shipID
# 346
# the depotID
# 9
# rec entire:
# 362
# sen entire:
# 9
# count
# 6950
# the shipID
# 346
# the depotID
# 10
# rec entire:
# 362
# sen entire:
# 10
# count
# 6951
# the shipID
# 346
# the depotID
# 14
# rec entire:
# 362
# sen entire:
# 14
# count
# 6952
# the shipID
# 346
# the depotID
# 6
# rec entire:
# 362
# sen entire:
# 6
# count
# 6953
# the shipID
# 346
# the depotID
# 10
# rec entire:
# 362
# sen entire:
# 10
# count
# 6954
# the shipID
# 346
# the depotID
# 9
# rec entire:
# 362
# sen entire:
# 9
# count
# 6955
# the shipID
# 346
# the depotID
# 6
# rec entire:
# 362
# sen entire:
# 6
# count
# 6956
# the shipID
# 346
# the depotID
# 6
# rec entire:
# 362
# sen entire:
# 6
# count
# 6957
# the shipID
# 346
# the depotID
# 9
# rec entire:
# 362
# sen entire:
# 9
# count
# 6958
# the shipID
# 346
# the depotID
# 10
# rec entire:
# 362
# sen entire:
# 10
# count
# 6959
# the shipID
# 346
# the depotID
# 9
# rec entire:
# 362
# sen entire:
# 9
# count
# 6960
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6961
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6962
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6963
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6964
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6965
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6966
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6967
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6968
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6969
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6970
# the shipID
# 347
# the depotID
# 12
# rec entire:
# 363
# sen entire:
# 12
# count
# 6971
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6972
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6973
# the shipID
# 347
# the depotID
# 9
# rec entire:
# 363
# sen entire:
# 9
# count
# 6974
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6975
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6976
# the shipID
# 347
# the depotID
# 12
# rec entire:
# 363
# sen entire:
# 12
# count
# 6977
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6978
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6979
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6980
# the shipID
# 347
# the depotID
# 9
# rec entire:
# 363
# sen entire:
# 9
# count
# 6981
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6982
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6983
# the shipID
# 347
# the depotID
# 9
# rec entire:
# 363
# sen entire:
# 9
# count
# 6984
# the shipID
# 347
# the depotID
# 10
# rec entire:
# 363
# sen entire:
# 10
# count
# 6985
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6986
# the shipID
# 347
# the depotID
# 12
# rec entire:
# 363
# sen entire:
# 12
# count
# 6987
# the shipID
# 347
# the depotID
# 9
# rec entire:
# 363
# sen entire:
# 9
# count
# 6988
# the shipID
# 347
# the depotID
# 1
# rec entire:
# 363
# sen entire:
# 1
# count
# 6989
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 6990
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 6991
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 6992
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 6993
# the shipID
# 348
# the depotID
# 10
# rec entire:
# 364
# sen entire:
# 10
# count
# 6994
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 6995
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 6996
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 6997
# the shipID
# 348
# the depotID
# 10
# rec entire:
# 364
# sen entire:
# 10
# count
# 6998
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 6999
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 7000
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 7001
# the shipID
# 348
# the depotID
# 10
# rec entire:
# 364
# sen entire:
# 10
# count
# 7002
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7003
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7004
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 7005
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 7006
# the shipID
# 348
# the depotID
# 12
# rec entire:
# 364
# sen entire:
# 12
# count
# 7007
# the shipID
# 348
# the depotID
# 12
# rec entire:
# 364
# sen entire:
# 12
# count
# 7008
# the shipID
# 348
# the depotID
# 10
# rec entire:
# 364
# sen entire:
# 10
# count
# 7009
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 7010
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7011
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7012
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7013
# the shipID
# 348
# the depotID
# 9
# rec entire:
# 364
# sen entire:
# 9
# count
# 7014
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7015
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7016
# the shipID
# 348
# the depotID
# 12
# rec entire:
# 364
# sen entire:
# 12
# count
# 7017
# the shipID
# 348
# the depotID
# 1
# rec entire:
# 364
# sen entire:
# 1
# count
# 7018
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7019
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7020
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7021
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7022
# the shipID
# 349
# the depotID
# 13
# rec entire:
# 365
# sen entire:
# 13
# count
# 7023
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7024
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7025
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7026
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7027
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7028
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7029
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7030
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7031
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7032
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7033
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7034
# the shipID
# 349
# the depotID
# 13
# rec entire:
# 365
# sen entire:
# 13
# count
# 7035
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7036
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7037
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7038
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7039
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7040
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7041
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7042
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7043
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7044
# the shipID
# 349
# the depotID
# 13
# rec entire:
# 365
# sen entire:
# 13
# count
# 7045
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7046
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7047
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7048
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7049
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7050
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7051
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7052
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7053
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7054
# the shipID
# 349
# the depotID
# 13
# rec entire:
# 365
# sen entire:
# 13
# count
# 7055
# the shipID
# 349
# the depotID
# 13
# rec entire:
# 365
# sen entire:
# 13
# count
# 7056
# the shipID
# 349
# the depotID
# 10
# rec entire:
# 365
# sen entire:
# 10
# count
# 7057
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7058
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7059
# the shipID
# 349
# the depotID
# 9
# rec entire:
# 365
# sen entire:
# 9
# count
# 7060
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7061
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7062
# the shipID
# 349
# the depotID
# 2
# rec entire:
# 365
# sen entire:
# 2
# count
# 7063
# the shipID
# 350
# the depotID
# 9
# rec entire:
# 366
# sen entire:
# 9
# count
# 7064
# the shipID
# 350
# the depotID
# 3
# rec entire:
# 366
# sen entire:
# 3
# count
# 7065
# the shipID
# 350
# the depotID
# 10
# rec entire:
# 366
# sen entire:
# 10
# count
# 7066
# the shipID
# 350
# the depotID
# 9
# rec entire:
# 366
# sen entire:
# 9
# count
# 7067
# the shipID
# 350
# the depotID
# 3
# rec entire:
# 366
# sen entire:
# 3
# count
# 7068
# the shipID
# 350
# the depotID
# 10
# rec entire:
# 366
# sen entire:
# 10
# count
# 7069
# the shipID
# 350
# the depotID
# 9
# rec entire:
# 366
# sen entire:
# 9
# count
# 7070
# the shipID
# 350
# the depotID
# 9
# rec entire:
# 366
# sen entire:
# 9
# count
# 7071
# the shipID
# 350
# the depotID
# 3
# rec entire:
# 366
# sen entire:
# 3
# count
# 7072
# the shipID
# 350
# the depotID
# 14
# rec entire:
# 366
# sen entire:
# 14
# count
# 7073
# the shipID
# 350
# the depotID
# 3
# rec entire:
# 366
# sen entire:
# 3
# count
# 7074
# the shipID
# 350
# the depotID
# 14
# rec entire:
# 366
# sen entire:
# 14
# count
# 7075
# the shipID
# 350
# the depotID
# 3
# rec entire:
# 366
# sen entire:
# 3
# count
# 7076
# the shipID
# 351
# the depotID
# 9
# rec entire:
# 367
# sen entire:
# 9
# count
# 7077
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7078
# the shipID
# 351
# the depotID
# 9
# rec entire:
# 367
# sen entire:
# 9
# count
# 7079
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7080
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7081
# the shipID
# 351
# the depotID
# 10
# rec entire:
# 367
# sen entire:
# 10
# count
# 7082
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7083
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7084
# the shipID
# 351
# the depotID
# 9
# rec entire:
# 367
# sen entire:
# 9
# count
# 7085
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7086
# the shipID
# 351
# the depotID
# 9
# rec entire:
# 367
# sen entire:
# 9
# count
# 7087
# the shipID
# 351
# the depotID
# 14
# rec entire:
# 367
# sen entire:
# 14
# count
# 7088
# the shipID
# 351
# the depotID
# 10
# rec entire:
# 367
# sen entire:
# 10
# count
# 7089
# the shipID
# 351
# the depotID
# 10
# rec entire:
# 367
# sen entire:
# 10
# count
# 7090
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7091
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7092
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7093
# the shipID
# 351
# the depotID
# 9
# rec entire:
# 367
# sen entire:
# 9
# count
# 7094
# the shipID
# 351
# the depotID
# 14
# rec entire:
# 367
# sen entire:
# 14
# count
# 7095
# the shipID
# 351
# the depotID
# 9
# rec entire:
# 367
# sen entire:
# 9
# count
# 7096
# the shipID
# 351
# the depotID
# 14
# rec entire:
# 367
# sen entire:
# 14
# count
# 7097
# the shipID
# 351
# the depotID
# 14
# rec entire:
# 367
# sen entire:
# 14
# count
# 7098
# the shipID
# 351
# the depotID
# 5
# rec entire:
# 367
# sen entire:
# 5
# count
# 7099
# the shipID
# 351
# the depotID
# 10
# rec entire:
# 367
# sen entire:
# 10
# count
# 7100
# the shipID
# 351
# the depotID
# 9
# rec entire:
# 367
# sen entire:
# 9
# count
# 7101
# the shipID
# 351
# the depotID
# 10
# rec entire:
# 367
# sen entire:
# 10
# count
# 7102
# the shipID
# 351
# the depotID
# 10
# rec entire:
# 367
# sen entire:
# 10
# count
# 7103
#                                      Receiver Receiver_ID  Receiver Lat  \
# 0           10th Court, Santa Monica, CA90403           1     34.019890
# 1           10th Court, Santa Monica, CA90403           1     34.019890
# 2           10th Court, Santa Monica, CA90403           1     34.019890
# 3           10th Court, Santa Monica, CA90403           1     34.019890
# 4           10th Court, Santa Monica, CA90403           1     34.019890
# ...                                       ...         ...           ...
# 7099  Yorkshire Avenue, Santa Monica, CA90404         351     34.026252
# 7100  Yorkshire Avenue, Santa Monica, CA90404         351     34.026252
# 7101  Yorkshire Avenue, Santa Monica, CA90404         351     34.026252
# 7102  Yorkshire Avenue, Santa Monica, CA90404         351     34.026252
# 7103  Yorkshire Avenue, Santa Monica, CA90404         351     34.026252
#
#       Receiver Lon Receiver_ZEDZ            Sender Sender_ID  Sender Lat  \
# 0      -118.488409             0               UPS         9   34.051950
# 1      -118.488409             0             FedEx        12   34.023789
# 2      -118.488409             0             FedEx        12   34.023789
# 3      -118.488409             0              USPS         5   34.015040
# 4      -118.488409             0              USPS         5   34.015040
# ...            ...           ...               ...       ...         ...
# 7099   -118.461364             0              USPS         5   34.015040
# 7100   -118.461364             0  Amazon Logistics        10   33.984066
# 7101   -118.461364             0               UPS         9   34.051950
# 7102   -118.461364             0  Amazon Logistics        10   33.984066
# 7103   -118.461364             0  Amazon Logistics        10   33.984066
#
#       Sender Lon Sender_ZEDZ  Distance
# 0    -118.431388           0      9448
# 1    -118.492240           0       783
# 2    -118.492240           0       783
# 3    -118.487514           1       740
# 4    -118.487514           1       740
# ...          ...         ...       ...
# 7099 -118.487514           1      4409
# 7100 -118.398651           0      9574
# 7101 -118.431388           0      5229
# 7102 -118.398651           0      9574
# 7103 -118.398651           0      9574
#
# [7104 rows x 11 columns]

# %% [markdown]
# <font size="5">Part II: Tour Formation + Part III: Network Assignment</font>
#
# The Tour Formation section groups shipments together into "tours", which are groups of shipments that are completed by a single vehicle before having to return to the depot. The basis of this section comes from this Thoen et al. 2020 paper, which is also used in the de Bok paper: https://reader.elsevier.com/reader/sd/pii/S1366554520306402?token=94FFE679DDC95AB4588FD05E915EF54B466EA50544AAD164F8C79AFFB3D97B92F41DC853C84CBE6E1BFC66821C332BA8&originRegion=us-east-1&originCreation=20220214151704
#
# This grouping is conducted in such a way that the tour is already arranged in an optimal way, also satisfying Part III.

# %%
#Tours without ZEDZ

UPS_tours = []
Amazon_tours = []
USPS_tours = []
FedEx_tours = []
#Our analysis found that diesel vehicles can carry 30 shipments before having to return to the depot
stops_per_vehicle = 30
max_dist = 20000000000

UPS_shipments = shipment_df.loc[shipment_df["Sender"] == "UPS"]
Amazon_shipments = shipment_df.loc[shipment_df["Sender"] == "Amazon Logistics"]
USPS_shipments = shipment_df.loc[shipment_df["Sender"] == "USPS"]
FedEx_shipments = shipment_df.loc[shipment_df["Sender"] == "FedEx"]

#Calculates the Euclidian distance between two locations
def calc_dist(A_lat, A_lon, B_lat, B_lon):
    dist = ((((A_lon - B_lon )**2) + ((A_lat - B_lat)**2) )**0.5)
    return dist

#Returns the actual driving distance between two locations
def calc_dist_nodes(A_ID, B_ID):
    #convert A_ID to its entire_node_ID
    A_node = entire_nodes[entire_nodes['street_id'] == A_ID]
    A_entire_ID = A_node.iloc[0]["ID"]
    
    #convert B_ID to its entire_node_ID
    B_node = entire_nodes[entire_nodes['street_id'] == B_ID]
    B_entire_ID = B_node.iloc[0]["ID"]
    
    poss_depo_arcs = depot_arcs[depot_arcs['origin_id'] == A_entire_ID]
    the_arc = poss_depo_arcs[poss_depo_arcs['destination_id'] == B_entire_ID]
    the_arc_dist = the_arc.iloc[0]['Distance in meter']
    return the_arc_dist

#The following functions generate a list of dataframes for each company.
#Each dataframe in these lists represent a single tour.
def UPS_tour_formation():
    remaining_shipments = pd.DataFrame.copy(UPS_shipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                
        else:
            UPS_tours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            if len(remaining_shipments.index) > 0:
                the_shipment = remaining_shipments.iloc[[0]]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    if len(tour_df.index) > 0:
        UPS_tours.append(tour_df)
        
def Amazon_tour_formation():
    remaining_shipments = pd.DataFrame.copy(Amazon_shipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            Amazon_tours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    Amazon_tours.append(tour_df)
    
def USPS_tour_formation():
    remaining_shipments = pd.DataFrame.copy(USPS_shipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            USPS_tours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    USPS_tours.append(tour_df)
    
def FedEx_tour_formation():
    remaining_shipments = pd.DataFrame.copy(FedEx_shipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            FedEx_tours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    FedEx_tours.append(tour_df)
    


UPS_tour_formation()
Amazon_tour_formation()
USPS_tour_formation()
FedEx_tour_formation()

# %%
#Tours with ZEDZ policy
UPS_Ztours = []
Amazon_Ztours = []
USPS_Ztours = []
FedEx_Ztours = []
UPS_nZtours = []
Amazon_nZtours = []
USPS_nZtours = []
FedEx_nZtours = []
max_dist = 200

UPS_Zshipments = shipment_df.loc[shipment_df["Sender"] == "UPS"]
UPS_Zshipments =  UPS_Zshipments[(UPS_Zshipments["Receiver_ZEDZ"] == 1) | (UPS_Zshipments["Sender_ZEDZ"] == 1)]
Amazon_Zshipments = shipment_df.loc[shipment_df["Sender"] == "Amazon Logistics"]
Amazon_Zshipments = Amazon_Zshipments[(Amazon_Zshipments["Receiver_ZEDZ"] == 1) | (Amazon_Zshipments["Sender_ZEDZ"] == 1)]
USPS_Zshipments = shipment_df.loc[shipment_df["Sender"] == "USPS"]
USPS_Zshipments = USPS_Zshipments[(USPS_Zshipments["Receiver_ZEDZ"] == 1) | (USPS_Zshipments["Sender_ZEDZ"] == 1)]
FedEx_Zshipments = shipment_df.loc[shipment_df["Sender"] == "FedEx"]
FedEx_Zshipments = FedEx_Zshipments[(FedEx_Zshipments["Receiver_ZEDZ"] == 1) | (FedEx_Zshipments["Sender_ZEDZ"] == 1)]

UPS_nZshipments = shipment_df.loc[shipment_df["Sender"] == "UPS"]
UPS_nZshipments =  UPS_nZshipments[(UPS_nZshipments["Receiver_ZEDZ"] == 0)]
UPS_nZshipments = UPS_nZshipments[(UPS_nZshipments["Sender_ZEDZ"] == 0)]
Amazon_nZshipments = shipment_df.loc[shipment_df["Sender"] == "Amazon Logistics"]
Amazon_nZshipments = Amazon_nZshipments[(Amazon_nZshipments["Receiver_ZEDZ"] == 0)]
Amazon_nZshipments = Amazon_nZshipments[(Amazon_nZshipments["Sender_ZEDZ"] == 0)]
USPS_nZshipments = shipment_df.loc[shipment_df["Sender"] == "USPS"]
USPS_nZshipments = USPS_nZshipments[(USPS_nZshipments["Receiver_ZEDZ"] == 0)]
USPS_nZshipments = USPS_nZshipments[(USPS_nZshipments["Sender_ZEDZ"] == 0)]
FedEx_nZshipments = shipment_df.loc[shipment_df["Sender"] == "FedEx"]
FedEx_nZshipments = FedEx_nZshipments[(FedEx_nZshipments["Receiver_ZEDZ"] == 0)]
FedEx_nZshipments = FedEx_nZshipments[(FedEx_nZshipments["Sender_ZEDZ"] == 0)]

tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
new_tour_df = pd.DataFrame.copy(tour_df)

#EV vehicles can do 33 stops from our analysis (mainly because they don't have to refuel as often)
stops_per_vehicle = 33


#The following functions generate a list of dataframes for each company and for whether the vehicle enters the ZEDZ zone.
#Each dataframe in these lists represent a single tour.
#Functions with "Z" are EVs that must enter the zone, and "nZ" do not
def UPS_Ztour_formation():
    remaining_shipments = pd.DataFrame.copy(UPS_Zshipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            UPS_Ztours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    UPS_Ztours.append(tour_df)
    
#This variable is redefined since the vehicles are now diesel
stops_per_vehicle = 30

def UPS_nZtour_formation():
    remaining_shipments = pd.DataFrame.copy(UPS_nZshipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            UPS_nZtours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    UPS_nZtours.append(tour_df)
   
stops_per_vehicle = 33

def Amazon_Ztour_formation():
    remaining_shipments = pd.DataFrame.copy(Amazon_Zshipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            Amazon_Ztours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    Amazon_Ztours.append(tour_df)
   
stops_per_vehicle = 30

def Amazon_nZtour_formation():
    remaining_shipments = pd.DataFrame.copy(Amazon_nZshipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            Amazon_nZtours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    Amazon_nZtours.append(tour_df)
    
stops_per_vehicle = 33

def USPS_Ztour_formation():
    remaining_shipments = pd.DataFrame.copy(USPS_Zshipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            USPS_Ztours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    USPS_Ztours.append(tour_df)
    
stops_per_vehicle = 30

def USPS_nZtour_formation():
    remaining_shipments = pd.DataFrame.copy(USPS_nZshipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    new_tour_df = pd.DataFrame.copy(tour_df)
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            USPS_nZtours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    USPS_nZtours.append(tour_df)
    
stops_per_vehicle = 33    

def FedEx_Ztour_formation():
    remaining_shipments = pd.DataFrame.copy(FedEx_Zshipments)
    tour_df = pd.DataFrame(columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"] )
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if (len(tour_df)) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            FedEx_Ztours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    FedEx_Ztours.append(tour_df)
    
    
stops_per_vehicle = 30    
    
def FedEx_nZtour_formation():
    remaining_shipments = pd.DataFrame.copy(FedEx_nZshipments)
    tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
    for i in range(remaining_shipments[remaining_shipments.columns[0]].count()):
        if len(remaining_shipments.index) == 0:
            break
        if len(tour_df) < stops_per_vehicle:
            if len(tour_df) == 0:
                the_shipment = remaining_shipments.iloc[:1]
                the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
                tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
                tour_df.reset_index()
            else:
                starting_lat = tour_df.iloc[0]["Receiver Lat"]
                starting_lon = tour_df.iloc[0]["Receiver Lon"]
                starting_ID = tour_df.iloc[0]["Receiver_ID"]
                min_dist = 1000000
                for k in range(len(remaining_shipments)):
                    q = remaining_shipments.iloc[[k]]
                    k_lat = q.iloc[0]["Receiver Lat"]
                    k_lon = q.iloc[0]["Receiver Lon"]
                    k_ID = q.iloc[0]["Receiver_ID"]
                    the_dist = calc_dist_nodes(starting_ID, k_ID)
                    if the_dist < min_dist:
                        the_chosen = q
                        min_dist = the_dist
                tour_df = pd.concat([tour_df, the_chosen], ignore_index = True)
                the_ship_id = the_chosen.iloc[0]["Receiver_ID"]
                remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
        else:
            FedEx_nZtours.append(tour_df)
            tour_df = pd.DataFrame( columns = [ "Receiver", "Receiver_ID", "Receiver Lat", "Receiver Lon", "Receiver_ZEDZ", "Sender", "Sender_ID", "Sender Lat", "Sender Lon", "Sender_ZEDZ"])
            the_shipment = remaining_shipments.iloc[[0]]
            the_ship_id = the_shipment.iloc[0]["Receiver_ID"]
            remaining_shipments = remaining_shipments[remaining_shipments["Receiver_ID"] != the_ship_id]
            tour_df = pd.concat([tour_df, the_shipment], ignore_index = True)
    FedEx_nZtours.append(tour_df)
    

    
UPS_Ztour_formation()
UPS_nZtour_formation()
Amazon_Ztour_formation()
Amazon_nZtour_formation()
USPS_Ztour_formation()
USPS_nZtour_formation()
FedEx_Ztour_formation()
FedEx_nZtour_formation()

# %%
#Calculate Distances
#This section calculates the total vehicle miles driven under each scenario, company, and type of vehicle.

#Status Quo - No ZEDZ
UPS_dist = 0
for i in range(len(UPS_tours)):
    the_tour = UPS_tours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            UPS_dist = UPS_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            UPS_dist = UPS_dist + calc_dist_nodes(start_id, end_id)
Amazon_dist = 0
for i in range(len(Amazon_tours)):
    the_tour = Amazon_tours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            Amazon_dist = Amazon_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            Amazon_dist = Amazon_dist + calc_dist_nodes(start_id, end_id)
USPS_dist = 0
for i in range(len(USPS_tours)):
    the_tour = USPS_tours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            USPS_dist = USPS_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            USPS_dist = USPS_dist + calc_dist_nodes(start_id, end_id)
FedEx_dist = 0
for i in range(len(FedEx_tours)):
    the_tour = FedEx_tours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            FedEx_dist = FedEx_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            FedEx_dist = FedEx_dist + calc_dist_nodes(start_id, end_id) 
    
total_dist_Status_Quo = UPS_dist + Amazon_dist + USPS_dist + FedEx_dist
    
    
#Mandatory ZEDZ
#Diesel Meters
UPS_nZ_dist = 0
for i in range(len(UPS_nZtours)):
    the_tour = UPS_nZtours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            UPS_nZ_dist = UPS_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            UPS_nZ_dist = UPS_nZ_dist + calc_dist_nodes(start_id, end_id)
Amazon_nZ_dist = 0
for i in range(len(Amazon_nZtours)):
    the_tour = Amazon_nZtours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            Amazon_nZ_dist = Amazon_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            Amazon_nZ_dist = Amazon_nZ_dist + calc_dist_nodes(start_id, end_id)
USPS_nZ_dist = 0
for i in range(len(USPS_nZtours)):
    the_tour = USPS_nZtours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            USPS_nZ_dist = USPS_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            USPS_nZ_dist = USPS_nZ_dist + calc_dist_nodes(start_id, end_id)
FedEx_nZ_dist = 0
for i in range(len(FedEx_nZtours)):
    the_tour = FedEx_nZtours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            FedEx_nZ_dist = FedEx_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            FedEx_nZ_dist = FedEx_nZ_dist + calc_dist_nodes(start_id, end_id)
    
total_dist_Man_Dies = FedEx_nZ_dist + USPS_nZ_dist + Amazon_nZ_dist + UPS_nZ_dist

#EV Meters
UPS_Z_dist = 0
for i in range(len(UPS_Ztours)):
    the_tour = UPS_Ztours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            UPS_Z_dist = UPS_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            UPS_Z_dist = UPS_Z_dist + calc_dist_nodes(start_id, end_id)
Amazon_Z_dist = 0
for i in range(len(Amazon_Ztours)):
    the_tour = Amazon_Ztours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            Amazon_Z_dist = Amazon_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            Amazon_Z_dist = Amazon_Z_dist + calc_dist_nodes(start_id, end_id)
USPS_Z_dist = 0
for i in range(len(USPS_Ztours)):
    the_tour = USPS_Ztours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            USPS_Z_dist = USPS_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            USPS_Z_dist = USPS_Z_dist + calc_dist_nodes(start_id, end_id)
FedEx_Z_dist = 0
for i in range(len(FedEx_Ztours)):
    the_tour = FedEx_Ztours[i]
    for j in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            FedEx_Z_dist = FedEx_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[j-1]["Receiver_ID"]
            end_id = the_tour.iloc[j]["Receiver_ID"]
            FedEx_Z_dist = FedEx_Z_dist + calc_dist_nodes(start_id, end_id)
    
total_dist_Man_EV = UPS_Z_dist + Amazon_Z_dist + USPS_Z_dist + FedEx_Z_dist

total_dist_mandatory = total_dist_Man_Dies + total_dist_Man_EV

# %%
#Calculate total tours

#Status Quo - No ZEDZ
UPS_tours_count = len(UPS_tours)

Amazon_tours_count = len(Amazon_tours)

USPS_tours_count = len(USPS_tours)

FedEx_tours_count = len(FedEx_tours)
    
total_tours_Status_Quo = UPS_tours_count + Amazon_tours_count + USPS_tours_count + FedEx_tours_count

#Mandatory ZEDZ
#Diesel tours
UPS_nZ_tours_count = len(UPS_nZtours)

Amazon_nZ_tours_count = len(Amazon_nZtours)

USPS_nZ_tours_count = len(USPS_nZtours)

FedEx_nZ_tours_count = len(FedEx_nZtours)

total_tours_Mand_Dies = UPS_nZ_tours_count + Amazon_nZ_tours_count + USPS_nZ_tours_count + FedEx_nZ_tours_count

#EV tours
UPS_Z_tours_count = len(UPS_Ztours) 

Amazon_Z_tours_count = len(Amazon_Ztours)

USPS_Z_tours_count = len(USPS_Ztours)

FedEx_Z_tours_count = len(FedEx_Ztours)

total_tours_Mand_EV = UPS_Z_tours_count  + Amazon_Z_tours_count + USPS_Z_tours_count + FedEx_Z_tours_count

total_tours_Mand = total_tours_Mand_Dies + total_tours_Mand_EV

# %%
#Create dataframes of dist traveled

#status quo
status_quo = pd.DataFrame( columns = ["UPS_dist", "Amazon_dist", "USPS_dist", "FedEx_dist", "Total_dist" ])
status_quo["UPS_dist"] = [UPS_dist]
status_quo["Amazon_dist"] = [Amazon_dist]
status_quo["USPS_dist"] = [USPS_dist]
status_quo["FedEx_dist"] = [FedEx_dist]
status_quo["Total_dist"] = [total_dist_Status_Quo]


#mandatory ZEDZ
mandatory_ZEDZ = pd.DataFrame( columns = ["UPS_nZdist", "Amazon_nZdist", "USPS_nZdist", "FedEx_nZdist", "Total_nZdist", "UPS_Zdist", "Amazon_Zdist", "USPS_Zdist", "FedEx_Zdist", "Total_Zdist", "Total_dist" ])
mandatory_ZEDZ["UPS_nZdist"] = [UPS_nZ_dist]
mandatory_ZEDZ["Amazon_nZdist"] = [Amazon_nZ_dist]
mandatory_ZEDZ["USPS_nZdist"] = [USPS_nZ_dist]
mandatory_ZEDZ["FedEx_nZdist"] = [FedEx_nZ_dist]
mandatory_ZEDZ["Total_nZdist"] = [total_dist_Man_Dies]

mandatory_ZEDZ["UPS_Zdist"] = [UPS_Z_dist]
mandatory_ZEDZ["Amazon_Zdist"] = [Amazon_Z_dist]
mandatory_ZEDZ["USPS_Zdist"] = [USPS_Z_dist]
mandatory_ZEDZ["FedEx_Zdist"] = [FedEx_Z_dist]
mandatory_ZEDZ["Total_Zdist"] = [total_dist_Man_EV]

mandatory_ZEDZ["Total_dist"] = [total_dist_mandatory]

#Create dataframes of tours conducted
#status quo
status_quo_tours = pd.DataFrame( columns = ["UPS_tours", "Amazon_tours", "USPS_tours", "FedEx_tours", "Total_tours" ])
status_quo_tours["UPS_tours"] = [UPS_tours_count]
status_quo_tours["Amazon_tours"] = [Amazon_tours_count]
status_quo_tours["USPS_tours"] = [USPS_tours_count]
status_quo_tours["FedEx_tours"] = [FedEx_tours_count]
status_quo_tours["Total_tours"] = [total_tours_Status_Quo]

#mandatory ZEDZ
mandatory_ZEDZ_tours = pd.DataFrame( columns = ["UPS_nZ_tours", "Amazon_nZ_tours", "USPS_nZ_tours", "FedEx_nZ_tours", "Total_nZ_tours", "UPS_Z_tours", "Amazon_Z_tours", "USPS_Z_tours", "FedEx_Z_tours", "Total_Z_tours", "Total_tours" ])
mandatory_ZEDZ_tours["UPS_nZ_tours"] = [UPS_nZ_tours_count]
mandatory_ZEDZ_tours["Amazon_nZ_tours"] = [Amazon_nZ_tours_count]
mandatory_ZEDZ_tours["USPS_nZ_tours"] = [USPS_nZ_tours_count]
mandatory_ZEDZ_tours["FedEx_nZ_tours"] = [FedEx_nZ_tours_count]
mandatory_ZEDZ_tours["Total_nZ_tours"] = [total_tours_Mand_Dies]

mandatory_ZEDZ_tours["UPS_Z_tours"] = [UPS_Z_tours_count]
mandatory_ZEDZ_tours["Amazon_Z_tours"] = [Amazon_Z_tours_count]
mandatory_ZEDZ_tours["USPS_Z_tours"] = [USPS_Z_tours_count]
mandatory_ZEDZ_tours["FedEx_Z_tours"] = [FedEx_Z_tours_count]
mandatory_ZEDZ_tours["Total_Z_tours"] = [total_tours_Mand_EV]

mandatory_ZEDZ_tours["Total_tours"] = [total_tours_Mand]

# %%
status_quo.to_excel('FinalResults - status quo dist.xlsx')

# %%
mandatory_ZEDZ.to_excel('FinalResults - mandatory ZEDZ dist.xlsx')

# %%
status_quo_tours.to_excel('FinalResults - status quo tours.xlsx')

# %%
mandatory_ZEDZ_tours.to_excel('FinalResults - mandatory ZEDZ tours.xlsx')

# %%
#Generate distance per tour
#status quo
status_quo_vehicles = pd.DataFrame(columns = ["Company", "Vehicle", "Tour", "Distance by tour" ])
company = []
vehicle = []
tour = []
Distance_tour = []
Distance_vehicle = []
vehicle_number = 1
tour_num = 0
j = 0
for i in range(len(UPS_tours)):
    tour_num += 1
    tour.append(tour_num)
    company.append("UPS")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(UPS_tours) - 1:
            vehicle_number += 1
    the_tour = UPS_tours[i]
    UPS_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            UPS_dist = UPS_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            UPS_dist = UPS_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(UPS_dist)
j = 0
vehicle_number += 1
for i in range(len(Amazon_tours)):
    tour_num += 1
    tour.append(tour_num)
    company.append("Amazon")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(Amazon_tours) - 1:
            vehicle_number += 1
    the_tour = Amazon_tours[i]
    Amazon_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            Amazon_dist = Amazon_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            Amazon_dist = Amazon_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(Amazon_dist)
    
j = 0
vehicle_number += 1
for i in range(len(USPS_tours)):
    tour_num += 1
    tour.append(tour_num)
    company.append("USPS")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(USPS_tours) - 1:
            vehicle_number += 1
    the_tour = USPS_tours[i]
    USPS_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if j == 0: 
            USPS_dist = USPS_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            USPS_dist = USPS_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(USPS_dist)

j = 0
vehicle_number += 1
for i in range(len(FedEx_tours)):
    tour_num += 1
    tour.append(tour_num)
    company.append("FedEx")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(FedEx_tours) - 1:
            vehicle_number += 1
    the_tour = FedEx_tours[i]
    FedEx_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            FedEx_dist = FedEx_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            FedEx_dist = FedEx_dist + calc_dist_nodes(start_id, end_id) 
    Distance_tour.append(FedEx_dist)

status_quo_vehicles["Company"] = company
status_quo_vehicles["Vehicle"] = vehicle
status_quo_vehicles["Tour"] = tour
status_quo_vehicles["Distance by tour"] = Distance_tour

temp = status_quo_vehicles.groupby(["Vehicle"]).sum()
temp = temp.rename(columns={"Distance by tour": "Distance by vehicle"})
temp = temp.drop(["Tour"], axis = 1)

status_quo_vehicles = pd.merge(status_quo_vehicles, temp, on = "Vehicle")


#Mandatory ZEDZ
mandatory_vehicles = pd.DataFrame(columns = ["Company", "Vehicle", "Tour", "Distance by tour", "EV" ])
company = []
vehicle = []
tour = []
Distance_tour = []
Distance_vehicle = []
EV = []
vehicle_number = 1
tour_num = 0
j = 0
for i in range(len(UPS_nZtours)):
    tour_num += 1
    tour.append(tour_num)
    EV.append(0)
    company.append("UPS")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(UPS_nZtours) - 1:
            vehicle_number += 1
    the_tour = UPS_nZtours[i]
    UPS_nZ_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            UPS_nZ_dist = UPS_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            UPS_nZ_dist = UPS_nZ_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(UPS_nZ_dist)
j = 0
vehicle_number += 1
for i in range(len(Amazon_nZtours)):
    tour_num += 1
    tour.append(tour_num)
    EV.append(0)
    company.append("Amazon")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(Amazon_nZtours) - 1:
            vehicle_number += 1
    the_tour = Amazon_nZtours[i]
    Amazon_nZ_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            Amazon_nZ_dist = Amazon_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            Amazon_nZ_dist = Amazon_nZ_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(Amazon_nZ_dist)
    
j = 0
vehicle_number += 1
for i in range(len(USPS_nZtours)):
    tour_num += 1
    tour.append(tour_num)
    EV.append(0)
    company.append("USPS")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(USPS_nZtours) - 1:
            vehicle_number += 1
    the_tour = USPS_nZtours[i]
    USPS_nZ_dist = 0 
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            USPS_nZ_dist = USPS_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            USPS_nZ_dist = USPS_nZ_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(USPS_nZ_dist)
    
j = 0
vehicle_number += 1
for i in range(len(FedEx_nZtours)):
    tour_num += 1
    tour.append(tour_num)
    EV.append(0)
    company.append("FedEx")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(FedEx_nZtours) - 1:
            vehicle_number += 1
    the_tour = FedEx_nZtours[i]
    FedEx_nZ_dist = 0 
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            FedEx_nZ_dist = FedEx_nZ_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            FedEx_nZ_dist = FedEx_nZ_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(FedEx_nZ_dist)
    
j = 0
vehicle_number += 1
for i in range(len(UPS_Ztours)):
    tour_num += 1
    tour.append(tour_num)
    company.append("UPS")
    EV.append(1)
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(UPS_Ztours) - 1:
            vehicle_number += 1
    the_tour = UPS_Ztours[i]
    UPS_Z_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            UPS_Z_dist = UPS_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            UPS_Z_dist = UPS_Z_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(UPS_Z_dist)
    
j = 0
vehicle_number += 1
for i in range(len(Amazon_Ztours)):
    tour_num += 1
    tour.append(tour_num)
    EV.append(1)
    company.append("Amazon")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(Amazon_Ztours) - 1:
            vehicle_number += 1
    the_tour = Amazon_Ztours[i]
    Amazon_Z_dist = 0
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            Amazon_Z_dist = Amazon_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            Amazon_Z_dist = Amazon_Z_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(Amazon_Z_dist)

j = 0
vehicle_number += 1
for i in range(len(USPS_Ztours)):
    tour_num += 1
    tour.append(tour_num)
    company.append("USPS")
    EV.append(1)
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(USPS_Ztours) - 1:
            vehicle_number += 1
    the_tour = USPS_Ztours[i]
    USPS_Z_dist = 0 
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            USPS_Z_dist = USPS_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            USPS_Z_dist = USPS_Z_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(USPS_Z_dist)
    
j = 0
vehicle_number += 1
for i in range(len(FedEx_Ztours)):
    tour_num += 1
    tour.append(tour_num)
    EV.append(1)
    company.append("FedEx")
    if j == 0:
        vehicle.append(vehicle_number)
        j = 1
    elif j == 1:
        j = 0
        vehicle.append(vehicle_number)
        if i != len(FedEx_Ztours) - 1:
            vehicle_number += 1
    the_tour = FedEx_Ztours[i]
    FedEx_Z_dist = 0 
    for h in range(the_tour[the_tour.columns[0]].count()):
        if h == 0: 
            FedEx_Z_dist = FedEx_Z_dist + the_tour.iloc[0]["Distance"]
        else:
            start_id = the_tour.iloc[h-1]["Receiver_ID"]
            end_id = the_tour.iloc[h]["Receiver_ID"]
            FedEx_Z_dist = FedEx_Z_dist + calc_dist_nodes(start_id, end_id)
    Distance_tour.append(FedEx_Z_dist)
    
mandatory_vehicles["Company"] = company
mandatory_vehicles["Vehicle"] = vehicle
mandatory_vehicles["Tour"] = tour
mandatory_vehicles["Distance by tour"] = Distance_tour
mandatory_vehicles["EV"] = EV

temp = mandatory_vehicles.groupby(["Vehicle"]).sum()
temp = temp.rename(columns={"Distance by tour": "Distance by vehicle"})
temp = temp.drop(["Tour"], axis = 1)

mandatory_vehicles = pd.merge(mandatory_vehicles, temp, on = "Vehicle")

mandatory_vehicles = mandatory_vehicles.drop(["EV_y"], axis = 1)
mandatory_vehicles = mandatory_vehicles.rename(columns = {"EV_x": "EV"})

# %%
status_quo_vehicles.to_excel("FinalResults - status quo vehicles.xlsx")

# %%
mandatory_vehicles.to_excel("FinalResults - mandatory ZEDZ vehicles.xlsx")
