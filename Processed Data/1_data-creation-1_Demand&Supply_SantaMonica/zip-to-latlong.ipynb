# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import requests
import googlemaps
from itertools import tee

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
GOOGLE_API_KEY = 'AIzaSyBmfECYHJNQTwz4BF0kdzIQP5X8M7FQifo' 

def extract_lat_long_via_address(address_or_zipcode):
    lat, lng = None, None
    api_key = GOOGLE_API_KEY
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    endpoint = f"{base_url}?address={address_or_zipcode}&key={api_key}"
    # see how our endpoint includes our API key? Yes this is yet another reason to restrict the key
    r = requests.get(endpoint)
    if r.status_code not in range(200, 299):
        return None, None
    try:
        '''
        This try block incase any of our inputs are invalid. This is done instead
        of actually writing out handlers for all kinds of responses.
        '''
        results = r.json()['results'][0]
        lat = results['geometry']['location']['lat']
        lng = results['geometry']['location']['lng']
    except:
        pass
    return lat, lng

# %%
extract_lat_long_via_address("Park Drive 90404")
# Out:
# (34.086434, -118.247567)

# %%
data = pd.read_csv("address.csv",header=None).values.tolist()

# %%
for n in data:
    latlong = extract_lat_long_via_address(n)
    print(latlong)
# Out:
# (34.0198901, -118.4884089)
# (34.0198965, -118.4872614)
# (34.0198901, -118.4884089)
# (34.0198901, -118.4884089)
# (34.0198901, -118.4884089)
# (34.0198901, -118.4884089)
# (34.0198901, -118.4884089)
# (34.029789, -118.497364)
# (34.0242925, -118.4916917)
# (34.0242925, -118.4916917)
# (34.0253028, -118.4923773)
# (34.0194353, -118.4836409)
# (34.0185454, -118.4842621)
# (34.018562, -118.4834492)
# (34.018562, -118.4834492)
# (34.018562, -118.4834492)
# (34.0194353, -118.4836409)
# (34.0225107, -118.4846546)
# (34.0225107, -118.4846546)
# (34.0225107, -118.4846546)
# (34.0154722, -118.4758611)
# (34.0347845, -118.4968362)
# (34.0308827, -118.491201)
# (34.0244138, -118.4838081)
# (34.027893, -118.485935)
# (34.024171, -118.481585)
# (34.024171, -118.481585)
# (34.027893, -118.485935)
# (34.019349, -118.474101)
# (34.019349, -118.474101)
# (34.019349, -118.474101)
# (34.019349, -118.474101)
# (34.022168, -118.4749601)
# (34.034654, -118.490179)
# (34.034654, -118.490179)
# ...

# %%
data2 = pd.read_csv("depot_address.csv",header=None).values.tolist()

# %%
data2
# Out:
# [['1112 Montana Ave, Santa Monica, CA 90403'],
#  ['1626 Montana Ave, Santa Monica, CA 90403'],
#  ['1223 Wilshire Blvd, Santa Monica, CA 90403'],
#  ['1217 Wilshire Blvd, Santa Monica, CA 90403'],
#  ['1653 7th St, Santa Monica, CA 90404'],
#  ['2720 Neilson Way Fl 1, Santa Monica, CA 90405'],
#  ['313 Grand Blvd, Venice, CA 90291'],
#  ['3826 Grand View Blvd, Los Angeles, CA 90066'],
#  ['10690 Santa Monica Blvd, Los Angeles, CA 90025'],
#  ['5750 Mesmer Ave STE D, Culver City, CA 90230'],
#  ['408 Wilshire Blvd, Santa Monica, CA 90401'],
#  ['1006 Wilshire Blvd, Santa Monica, CA 90401'],
#  ['2300 Wilshire Blvd Suite 102, Santa Monica, CA 90403'],
#  ['2309 Santa Monica Blvd, Santa Monica, CA 90404'],
#  ['4170 Del Rey Ave, Marina Del Rey, CA 90292'],
#  ['13488 Maxella Ave Suite 300, Marina Del Rey, CA 90292']]

# %%
for n in data2:
    latlong2 = extract_lat_long_via_address(n)
    print(latlong2)
# Out:
# (34.030044, -118.497416)
# (34.0341588, -118.4924904)
# (34.0259349, -118.4903059)
# (34.0258613, -118.4904235)
# (34.0150398, -118.4875136)
# (33.9999542, -118.4829612)
# (33.9886406, -118.4694269)
# (34.0044458, -118.4301801)
# (34.0519496, -118.4313883)
# (33.984066, -118.3986511)
# (34.019282, -118.4977748)
# (34.0237888, -118.49224)
# (34.0332757, -118.4801333)
# (34.0310722, -118.4774046)
# (33.987807, -118.443532)
# (33.9858664, -118.442557)
